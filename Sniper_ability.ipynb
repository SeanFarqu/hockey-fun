# %% [markdown]
# # Sniper Ability

# %% [markdown]
# Granular PPT data presents the opportunity to calculate a precise location for which the shooter is targetting the goal frame. In the past, we could roughly see where the shooter is aiming on the net, but there was never the capability to calculate precise coordinates. The difference between a save and a goal can be a matter of inches. In this script, we use the precise coordinates for which the shooter is aiming at the goal frame, and calculate the distance to the nearest post/bar. This will give a measure of each players "sniper ability"/ their ability to "pick" the corners. This could be used as a feature of an Expected Goals (xG) model.

# %%
"""
Shots
Uses the shot records with the puck tracking adjacent to each shot record from the ShotEvents table
to calculate the coordinates of the puck when there is a shot and appends the calculation back 
to the original record.
Usage:
    sh init.sh
"""

# Module imports
import logging
import json
import os
import decimal
import time
import boto3

import pandas as pd
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

import numpy as np
from pandas import json_normalize
from decimal import Decimal
from datetime import timedelta, datetime
from scipy.signal import butter,filtfilt


from boto3.dynamodb.conditions import Key, Attr
from botocore.exceptions import ClientError
# from Producer_Helpers import DecimalEncoder

logger = logging
logger.basicConfig(format="%(asctime)s :: %(levelname)-5s :: %(message)s",
    level=os.environ.get('LOGGING_LEVEL'))

# AWS Resources
DYNAMODB = boto3.resource('dynamodb')
EVENT_TABLE = DYNAMODB.Table(os.environ.get('EVENT_TABLE', 'Event'))
SHOT_EVENTS_TABLE = DYNAMODB.Table(os.environ.get('SHOT_EVENTS_TABLE', 'ShotEvents'))

tomorrow = datetime.now() + timedelta(0.5)
TTL = tomorrow.timestamp()


def get_event():
    """Scan the Event table for events that have a timestamp
    within 12 hrs to now. Keep trying until call returns an event_id
    Return the event_id.
    """

    while True:

        try:
            logging.info("Getting the event_id from the Event table")
            now = int(time.time())
            response = EVENT_TABLE.scan(
                FilterExpression=Key('TimeStamp').between(
                    Decimal(now - 25000), Decimal(now)),
                ProjectionExpression="EventId",
            )
            event_id = (json.dumps(
                response['Items'][0]['EventId'])).strip('\"')

        except ClientError as e:
            logging.error("Error: EventId not found. {}".format(
                          e.response['Error']['Message']))
            logging.error("Retrying...")
            continue

        except IndexError as e:
            logging.error("Error: EventId not found. {}".format(str(e)))
                        #   e.response['Error']['Message'])
            logging.error("Retrying...")
            continue
        break

    return event_id

def get_shot_events(event_id = 'HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125'):
    """Query the Shot Events table to get the shot events for the given event_id.
    Return shot events as dataframe.
    """

    logger.info("Scanning Shot Events Table for shots...")

    try:
        response = SHOT_EVENTS_TABLE.scan(
            FilterExpression=Attr("EventId").eq(event_id),
            ProjectionExpression="MinorType, ShotUTC, PuckTracking, EndUTC",
        )
        shot_list = response["Items"]

        # Inspect if more pages available in the table
        while "LastEvaluatedKey" in response:
            response = SHOT_EVENTS_TABLE.scan(
                FilterExpression=Attr("EventId").eq(event_id),
                ProjectionExpression="MinorType, ShotUTC, PuckTracking, EndUTC",
                ExclusiveStartKey=response["LastEvaluatedKey"],
            )
            shot_list.extend(response["Items"])

    except ClientError as e:
        logger.info("Error: No data yet.", e.response["Error"]["Message"])

    except IndexError as e:
        logger.info("Error: No data yet.", e.response["Error"]["Message"])

    if len(shot_list) > 0:
        shot_event_df = json_normalize(shot_list)
        logger.info("Shots found.")
        return shot_event_df
    else:
        logger.info("No shot events created yet.")
        return pd.DataFrame() 


def butter_lowpass_filter(data):

    """
    This function applies a butterworth low-pass filter across an array.
    While a butterworth filter is traditionally used for cyclical noise, it works well in this application.


    :param data:    array, the data you would like filtered
    :return:        array, the filtered data
    """
    
    T = 4         # Sample Period
    fs = 60       # sample rate, Hz
    cutoff = 8    # desired cutoff frequency of the filter, Hz
    nyq = 0.5 * fs  # Nyquist Frequency
    order = 2       # sin wave can be approx represented as quadratic
    n = int(T * fs) # total number of samples
    
    normal_cutoff = cutoff / nyq
    # Get the filter coefficients 
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    # Apply the filter in both directions. This is how lag in filtering is avoided
    # Pad data with zeros before and after input signal
    padlen = 5 * max(len(a), len(b))
    data_padded = np.pad(data, (padlen,padlen), mode='constant', constant_values=0)
    y = filtfilt(b, a, data_padded)
    # remove padding from output signal
    y = y[padlen:-padlen]
    return y

def find_nearest(array, value):

    """
    This function takes an array and a supplied value, and finds the index of the closest value to the supplied value in the array
   
    :param array:   array, contains values
    :param value:   number, value from which you want to find the index to the nearest value
    :return:        int, index within the array nearest to the supplied value
    """

    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

def clean_string(string):
    # Remove anything that isn't a number or decimal
    cleaned_string = ''.join(filter(lambda char: char.isdigit() or char == '.', string))
    # Strip any extra decimal points or leading/trailing whitespace
    cleaned_string = cleaned_string.strip().strip('.')
    # Convert to decimal
    try:
        decimal_value = Decimal(cleaned_string)
    except:
        decimal_value = None
    return decimal_value

def shot_result_coords_new(shot_event_df):
    # globals
    NET_X_POSITION = 89

    # remove + replace quotations 
    # shot_event_df = shot_event_df.replace('""','"',regex=True)
    shot_event_df = shot_event_df.reset_index()

    # empty list for new col where updated calcs will be store for each row of df
    shot_outcome_coords = []

    # puck tracking
    for i in range(len(shot_event_df)):
        # check if rows haven't been updated
        if i+1 > len(shot_outcome_coords): 
            index = i
            col = "PuckTracking"
            cell_val = shot_event_df.iloc[index][col]
            puck_data = json_normalize(json.loads(cell_val))
        
            # start and end UTC's from record
            shot_start_time = shot_event_df.iloc[i]['ShotUTC']
            shot_start_time = float(shot_start_time)
            shot_end_time = shot_event_df.iloc[i]['EndUTC']
            start_index = find_nearest(puck_data['LocationUTC'], shot_start_time)
        
            # fill na for calculations
            puck_data[['Velocity.X', 'Velocity.Y', 'Velocity.Z', 'Location.Z']] = puck_data[['Velocity.X', 'Velocity.Y', 'Velocity.Z', 'Location.Z']].fillna(0)
            
            # FEATURE ENGINEERING
            velo_x = np.array(puck_data['Velocity.X'])
            velo_y = np.array(puck_data['Velocity.Y'])    
            velo_z = np.array(puck_data['Velocity.Z'])
            loc_x = np.array(puck_data['Location.X'])
            loc_y = np.array(puck_data['Location.Y'])
            loc_z = np.array(puck_data['Location.Z'])
            velo_z_adj = velo_z + (10)*(puck_data['LocationUTC']-puck_data['LocationUTC'][start_index])
            
            # new cols we'll use to make decisions on shots 
            abs_velo = (velo_x ** 2 + velo_y ** 2 + velo_z ** 2) ** 0.5
            vel_x_fil = np.array(butter_lowpass_filter(velo_x))
            vel_y_fil = np.array(butter_lowpass_filter(velo_y))
            vel_z_fil = np.array(butter_lowpass_filter(velo_z))
            vel_z_adj_fil = np.array(butter_lowpass_filter(velo_z_adj))
            vel_fil = np.array(butter_lowpass_filter(abs_velo))
            puck_data['vel_fil'] = vel_fil
            
            # which goal line should be used, when x is positive, use the positive one (89) otherwise use the neg one (-89)
            goal_line = np.where(loc_x >= 0, NET_X_POSITION, -NET_X_POSITION)
            
            intersection_point_y = (((goal_line - loc_x) / vel_x_fil) * vel_y_fil) + loc_y
            intersection_point_y_natural = (((goal_line - loc_x) / velo_x) * velo_y) + loc_y
            intersection_point_z = (((goal_line - loc_x) / vel_x_fil) * vel_z_fil) + loc_z
            intersection_point_z_natural = (((goal_line - loc_x) / velo_x) * velo_z) + loc_z
            intersection_point_z_adj = (((goal_line - loc_x) / velo_x) * velo_z_adj) + loc_z
            
            puck_data['inter_y'] = intersection_point_y
            puck_data['inter_y_unfil'] = intersection_point_y_natural
            puck_data['inter_z'] = intersection_point_z
            puck_data['inter_z_unfil'] = intersection_point_z_natural
            puck_data['inter_z_adj'] = intersection_point_z_adj
            
            #reset index
            puck_data = puck_data.reset_index()

            # trim puck tracking data
            puck_section = puck_data[(shot_start_time + 0.05 <= puck_data.LocationUTC) & (puck_data.LocationUTC <= shot_end_time)]
    
            # return coords based on which side of the ice puck is on at the end of the shot
            outside_crease_one = puck_section.loc[(puck_section['Location.X'] >= -83) 
                                            & ((puck_section['Location.Y'] >=4) | (puck_section['Location.Y'] <=-4))]
            outside_crease_two = puck_section.loc[(puck_section['Location.X'] <= 83) 
                                            & ((puck_section['Location.Y'] >=4) | (puck_section['Location.Y'] <=-4))]
            
            #no data
            if len(puck_section) <= 1:  
                puck_x = 0
                puck_y = 0
                puck_z = 0
                        
            # jam plays within crease, no time and space to pick a corner
            elif puck_section['Location.X'].iloc[-1] < 0 and len(outside_crease_one) == 0:
                puck_x = -89
                puck_y = 0
                puck_z = 0
                
            elif puck_section['Location.X'].iloc[-1] < 0 and len(outside_crease_one) != 0:
                puck_x = -89
                puck_y = outside_crease_one.iloc[-1]['inter_y']
                puck_z = outside_crease_one.iloc[-1]['inter_z_adj']
                
            elif puck_section['Location.X'].iloc[-1] > 0 and len(outside_crease_two) == 0:
                puck_x = 89
                puck_y = 0
                puck_z = 0
            
            elif puck_section['Location.X'].iloc[-1] > 0 and len(outside_crease_two) != 0:
                puck_x = 89
                puck_y = outside_crease_two.iloc[-1]['inter_y']
                puck_z = outside_crease_two.iloc[-1]['inter_z_adj']

            # convert to Decimal
            puck_x = clean_string(str(puck_x))
            puck_y = clean_string(str(puck_y))
            puck_z = clean_string(str(puck_z))

            # output as dict
            coords_xyz = {"puck_x": puck_x, "puck_y": puck_y, "puck_z": puck_z}

            # append to dict
            shot_outcome_coords.append(coords_xyz)
    
    shot_event_df['shot_outcome_coords'] = shot_outcome_coords
    
    return shot_event_df

# %%
# use code above or just use csv that I saved:
shot_events_df = pd.read_csv(f'shot_events_HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125.csv')

# %%
event_id = 'HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125'

# %%
shot_events_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 85 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               107 non-null    int64
#  1   index                    107 non-null    int64
#  2   EventId                  107 non-null    object
#  3   ShotUTC                  107 non-null    float64
#  4   Angle                    107 non-null    float64
#  5   Assist1Zone              4 non-null      object
#  6   Assist2Location_X        4 non-null      object
#  7   Assist2Location_Y        4 non-null      object
#  8   Assist2Zone              4 non-null      object
#  9   AssistLocation_X         4 non-null      object
#  10  AssistLocation_Y         4 non-null      object
#  11  Ballorpuck               107 non-null    int64
#  12  BlockerLocation_X        22 non-null     object
#  13  BlockerLocation_Y        20 non-null     object
#  14  BlockerZone              22 non-null     object
#  15  ClockMinutes             107 non-null    int64
#  16  ClockSeconds             107 non-null    int64
#  17  ClockTenths              107 non-null    int64
#  18  ClosestDefender          107 non-null    int64
#  19  ClosestDefenderDistance  107 non-null    float64
#  20  Confidence               107 non-null    int64
#  21  Descriptor               107 non-null    object
#  22  Distance                 107 non-null    int64
#  23  EndUTC                   107 non-null    float64
#  24  Goalie                   106 non-null    float64
#  25  GoalieAngle              106 non-null    object
#  26  HomeScore                107 non-null    int64
#  27  IsInHomePlateArea        107 non-null    bool
#  28  IsOfficial               107 non-null    bool
#  29  Location_X               107 non-null    object
#  30  Location_Y               101 non-null    object
#  31  MarkerId                 107 non-null    int64
#  32  MarkerUTC                107 non-null    float64
#  33  MinorType                107 non-null    object
#  34  NonGoalieShotBlocker     25 non-null     float64
#  35  OffGoalFrameLocation_X   70 non-null     object
#  36  OffGoalFrameLocation_Y   70 non-null     object
#  37  OffGoalFrameLocation_Z   42 non-null     float64
#  38  OfficialCode             107 non-null    int64
#  39  OnGoalFrameArea          4 non-null      object
#  40  OnGoalFrameAreaCode      4 non-null      float64
#  41  OnGoalFrameLocation_X    37 non-null     object
#  42  OnGoalFrameLocation_Y    37 non-null     object
#  43  OnGoalFrameLocation_Z    28 non-null     float64
#  44  Period                   107 non-null    int64
#  45  PeriodNum                107 non-null    int64
#  46  PlayersOnSurface_Ids     107 non-null    object
#  47  PlayersOnSurface_Teams   107 non-null    object
#  48  PuckTracking             107 non-null    object
#  49  PuckZone                 107 non-null    object
#  50  RevisionNum              107 non-null    int64
#  51  Shooter                  107 non-null    int64
#  52  shot_outcome_coords      107 non-null    object
#  53  ShotAssister             66 non-null     float64
#  54  ShotAssister2            4 non-null      float64
#  55  ShotBlockLocation_X      6 non-null      object
#  56  ShotBlockLocation_Y      6 non-null      object
#  57  ShotBlockLocation_Z      6 non-null      float64
#  58  ShotCode                 105 non-null    float64
#  59  ShotMissed               17 non-null     object
#  60  ShotMissedCode           17 non-null     float64
#  61  ShotResult               107 non-null    object
#  62  ShotType                 105 non-null    object
#  63  ShotVelocity_X           107 non-null    object
#  64  ShotVelocity_Y           107 non-null    object
#  65  ShotVelocity_Z           97 non-null     object
#  66  SituationCode            107 non-null    int64
#  67  SourceId                 107 non-null    object
#  68  SourceNativeMarkerId     107 non-null    int64
#  69  SourceType               107 non-null    object
#  70  Speed                    107 non-null    float64
#  71  TotalClockSec            107 non-null    int64
#  72  ttl                      107 non-null    float64
#  73  UpdateType               107 non-null    object
#  74  VisitorScore             107 non-null    int64
#  75  WasAwarded               107 non-null    bool
#  76  WasBlocked               6 non-null      object
#  77  WasEmptyNet              107 non-null    bool
#  78  WasGoal                  107 non-null    bool
#  79  WasOnTargetToGoal        107 non-null    bool
#  80  WasOwnGoal               107 non-null    bool
#  81  WasPenaltyShot           107 non-null    bool
#  82  WasSaved                 25 non-null     object
#  83  WasTipped                48 non-null     object
#  84  distance_to_nearest_bar  15 non-null     float64
# dtypes: bool(8), float64(18), int64(20), object(39)
# memory usage: 65.3+ KB

# %%
shot_events_df.head(10)
# Out:
#    Unnamed: 0  index                                EventId        ShotUTC  \
# 0           0      0  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637075.918
# 1           1      1  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637084.382
# 2           2      2  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637139.534
# 3           3      3  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637201.599
# 4           4      4  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637245.739
# 5           5      5  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637283.883
# 6           6      6  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637293.211
# 7           7      7  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637424.612
# 8           8      8  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637449.380
# 9           9      9  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637462.436
#
#     Angle Assist1Zone Assist2Location_X Assist2Location_Y Assist2Zone  \
# 0 120.473         NaN               NaN               NaN         NaN
# 1 139.297         NaN               NaN               NaN         NaN
# 2  49.826         NaN               NaN               NaN         NaN
# 3 138.615         NaN               NaN               NaN         NaN
# 4 167.427         NaN               NaN               NaN         NaN
# 5 156.414         NaN               NaN               NaN         NaN
# 6 128.160         NaN               NaN               NaN         NaN
# 7  60.234         NaN               NaN               NaN         NaN
# 8 138.553         NaN               NaN               NaN         NaN
# 9 140.241         NaN               NaN               NaN         NaN
#
#   AssistLocation_X  AssistLocation_Y  Ballorpuck BlockerLocation_X  \
# 0              NaN               NaN           1               NaN
# 1              NaN               NaN           1              '-65
# 2              NaN               NaN           1                50
# 3              NaN               NaN           1                49
# 4              NaN               NaN           1               NaN
# 5              NaN               NaN           1               NaN
# 6              NaN               NaN           1               NaN
# 7              NaN               NaN           1               NaN
# 8              NaN               NaN           1              '-63
# 9              NaN               NaN           1               NaN
#
#   BlockerLocation_Y   BlockerZone  ClockMinutes  ClockSeconds  ClockTenths  \
# 0               NaN           NaN            19            25            0
# 1                23  ZONE_DEFENSE            19            18            0
# 2                 6  ZONE_DEFENSE            18            23            0
# 3              '-28  ZONE_DEFENSE            17            47            0
# 4               NaN           NaN            17             2            0
# 5               NaN           NaN            16            25            0
# 6               NaN           NaN            16            15            0
# 7               NaN           NaN            15            16            0
# 8                19  ZONE_DEFENSE            14            53            0
# 9               NaN           NaN            14            38            0
#
#    ClosestDefender  ClosestDefenderDistance  Confidence  \
# 0            10044                    7.661         100
# 1            14048                    7.540         100
# 2            10052                   13.074         100
# 3            10052                   11.147         100
# 4            10055                    9.588         100
# 5            10002                    6.737         100
# 6            10023                   25.969         100
# 7            10028                   20.052         100
# 8            14048                    7.148         100
# 9            14077                   17.179         100
#
#                                           Descriptor  Distance         EndUTC  \
# 0  "HITS : E#8 19:25 - Shot. ONGOAL. V#17, Killorn."        40 1682637076.254
# 1  "HITS : E#201 19:18 - Shot. VBLOCKED. H#88, Ny...        33 1682637084.993
# 2  "HITS : E#10 18:23 - Shot. HBLOCKED. V#98, Ser...        39 1682637139.678
# 3  "HITS : E#11 17:47 - Shot. HBLOCKED. V#28, Cole."        48 1682637201.695
# 4  "HITS : E#12 17:02 - Shot. ONGOAL. V#86, Kuche...        39 1682637246.267
# 5  "HITS : E#13 16:25 - Shot. MISSED. V#14, Maroon."        18 1682637284.060
# 6  "HITS : E#14 16:15 - Shot. ONGOAL. V#24, Bogos...        66 1682637293.755
# 7  "HITS : E#18 15:16 - Shot. ONGOAL. V#86, Kuche...        58 1682637425.284
# 8  "HITS : E#19 14:53 - Shot. VBLOCKED. H#28, Laf...        32 1682637449.827
# 9  "HITS : E#20 14:38 - Shot. ONGOAL. H#12, Aston...        47 1682637464.052
#
#    Goalie  GoalieAngle  HomeScore  IsInHomePlateArea  IsOfficial Location_X  \
# 0   10035      118.999          0              False        True         54
# 1   14088      131.130          0              False        True       '-58
# 2   10035       82.913          0              False        True         34
# 3   10035      119.280          0              False        True         37
# 4   10035      166.320          0              False        True         79
# 5   10035      168.166          0              False        True         87
# 6   10035      122.075          0              False        True         33
# 7   10035       54.223          0              False        True         42
# 8   14088      128.315          0               True        True       '-57
# 9   14088      140.192          0              False        True       '-60
#
#   Location_Y  MarkerId      MarkerUTC   MinorType  NonGoalieShotBlocker  \
# 0       '-20       251 1682637079.347  EVENT_SHOT                   NaN
# 1         29       638 1682637083.347  EVENT_SHOT             14048.000
# 2          8      1646 1682637140.347  EVENT_SHOT             10052.000
# 3       '-36      2159 1682637205.149  EVENT_SHOT             10052.000
# 4       '-38      2388 1682637247.149  EVENT_SHOT                   NaN
# 5       '-18      2869 1682637285.149  EVENT_SHOT                   NaN
# 6       '-35      3213 1682637296.159  EVENT_SHOT                   NaN
# 7         34      1343 1682637426.651  EVENT_SHOT                   NaN
# 8         22      4979 1682637446.651  EVENT_SHOT             14048.000
# 9         38      1458 1682637464.552  EVENT_SHOT                   NaN
#
#   OffGoalFrameLocation_X OffGoalFrameLocation_Y  OffGoalFrameLocation_Z  \
# 0                    NaN                    NaN                     NaN
# 1    '-89.00000065042073    '-9.509935477439402                   9.384
# 2                     89    '-40.90091200792847                     NaN
# 3                     89     28.481090779431668                     NaN
# 4                     89      7.725706820225859                     NaN
# 5       88.9999962740467     '-7.69144567424054                   2.518
# 6                     89      9.047693354279708                     NaN
# 7                     89     10.024936052100067                   0.202
# 8    '-88.99999693742113    '-9.908430253441525                   7.670
# 9                    NaN                    NaN                     NaN
#
#    OfficialCode OnGoalFrameArea  OnGoalFrameAreaCode OnGoalFrameLocation_X  \
# 0    2022030125             NaN                  NaN                    89
# 1    2022030125             NaN                  NaN                   NaN
# 2    2022030125             NaN                  NaN                   NaN
# 3    2022030125             NaN                  NaN                   NaN
# 4    2022030125             NaN                  NaN                   NaN
# 5    2022030125             NaN                  NaN                   NaN
# 6    2022030125             NaN                  NaN                   NaN
# 7    2022030125             NaN                  NaN                   NaN
# 8    2022030125             NaN                  NaN                   NaN
# 9    2022030125             NaN                  NaN                  '-89
#
#   OnGoalFrameLocation_Y  OnGoalFrameLocation_Z  Period  PeriodNum  \
# 0    0.9021048726302325                  3.016       1          1
# 1                   NaN                    NaN       1          1
# 2                   NaN                    NaN       1          1
# 3                   NaN                    NaN       1          1
# 4                   NaN                    NaN       1          1
# 5                   NaN                    NaN       1          1
# 6                   NaN                    NaN       1          1
# 7                   NaN                    NaN       1          1
# 8                   NaN                    NaN       1          1
# 9  '-1.6013731279374248                  1.462       1          1
#
#                                 PlayersOnSurface_Ids  \
# 0  [{"S":"8473986"},{"S":"8475167"},{"S":"8476883...
# 1  [{"S":"8473986"},{"S":"8475167"},{"S":"8476883...
# 2  [{"S":"8474564"},{"S":"8476453"},{"S":"8476883...
# 3  [{"S":"8474013"},{"S":"8474567"},{"S":"8476883...
# 4  [{"S":"8474564"},{"S":"8475167"},{"S":"8476453...
# 5  [{"S":"8474013"},{"S":"8474034"},{"S":"8474567...
# 6  [{"S":"8473986"},{"S":"8474013"},{"S":"8474034...
# 7  [{"S":"8474564"},{"S":"8475167"},{"S":"8476453...
# 8  [{"S":"8474564"},{"S":"8475167"},{"S":"8476453...
# 9  [{"S":"8474564"},{"S":"8475167"},{"S":"8476453...
#
#                               PlayersOnSurface_Teams  \
# 0  [{"S":"VISITOR"},{"S":"VISITOR"},{"S":"VISITOR...
# 1  [{"S":"VISITOR"},{"S":"VISITOR"},{"S":"VISITOR...
# 2  [{"S":"VISITOR"},{"S":"VISITOR"},{"S":"VISITOR...
# 3  [{"S":"VISITOR"},{"S":"VISITOR"},{"S":"VISITOR...
# 4  [{"S":"VISITOR"},{"S":"VISITOR"},{"S":"VISITOR...
# 5  [{"S":"VISITOR"},{"S":"VISITOR"},{"S":"VISITOR...
# 6  [{"S":"VISITOR"},{"S":"VISITOR"},{"S":"VISITOR...
# 7  [{"S":"VISITOR"},{"S":"VISITOR"},{"S":"VISITOR...
# 8  [{"S":"VISITOR"},{"S":"VISITOR"},{"S":"VISITOR...
# 9  [{"S":"VISITOR"},{"S":"VISITOR"},{"S":"VISITOR...
#
#                                         PuckTracking      PuckZone  \
# 0  "[{"EntityId":"1","OnPlayingSurface":true,"Loc...  offense zone
# 1  "[{"EntityId":"1","OnPlayingSurface":true,"Loc...  offense zone
# 2  "[{"EntityId":"1","OnPlayingSurface":true,"Loc...  offense zone
# 3  "[{"EntityId":"1","OnPlayingSurface":true,"Loc...  offense zone
# 4  "[{"EntityId":"1","OnPlayingSurface":true,"Loc...  offense zone
# 5  "[{"EntityId":"1","OnPlayingSurface":true,"Loc...  offense zone
# 6  "[{"EntityId":"1","OnPlayingSurface":true,"Loc...  offense zone
# 7  "[{"EntityId":"1","OnPlayingSurface":true,"Loc...  offense zone
# 8  "[{"EntityId":"1","OnPlayingSurface":true,"Loc...  offense zone
# 9  "[{"EntityId":"1","OnPlayingSurface":true,"Loc...  offense zone
#
#    RevisionNum  Shooter  ShotAssister  ShotAssister2 ShotBlockLocation_X  \
# 0            9    14017           NaN            NaN                 NaN
# 1           16    10088           NaN            NaN                 NaN
# 2           13    14098     14021.000            NaN                 NaN
# 3           20    14028     14024.000            NaN                 NaN
# 4            6    14086     14091.000            NaN                 NaN
# 5           11    14014           NaN            NaN                 NaN
# 6           14    14024     14014.000            NaN                 NaN
# 7            4    14086     14077.000            NaN                 NaN
# 8           30    10028           NaN            NaN                 NaN
# 9            5    10012     10064.000            NaN                 NaN
#
#   ShotBlockLocation_Y  ShotBlockLocation_Z  ShotCode   ShotMissed  \
# 0                 NaN                  NaN   803.000          NaN
# 1                 NaN                  NaN   802.000          NaN
# 2                 NaN                  NaN   803.000          NaN
# 3                 NaN                  NaN   801.000          NaN
# 4                 NaN                  NaN   806.000          NaN
# 5                 NaN                  NaN   803.000  Wide of Net
# 6                 NaN                  NaN   801.000          NaN
# 7                 NaN                  NaN       NaN          NaN
# 8                 NaN                  NaN   803.000          NaN
# 9                 NaN                  NaN   801.000          NaN
#
#    ShotMissedCode ShotResult  ShotType       ShotVelocity_X  \
# 0             NaN    on goal     Wrist   108.36031186686796
# 1             NaN    blocked      Snap  '-53.48808717992693
# 2             NaN    blocked     Wrist   107.52880567641903
# 3             NaN    blocked      Slap    91.80526293833773
# 4             NaN    on goal  Backhand   13.316387687435496
# 5        1004.000     missed     Wrist    34.89910685297933
# 6             NaN    on goal      Slap    97.09568373031007
# 7             NaN    on goal       NaN     74.6850971392178
# 8             NaN    blocked     Wrist  '-63.96233906703373
# 9             NaN    on goal      Slap  '-71.17221680338302
#
#          ShotVelocity_Y      ShotVelocity_Z  SituationCode SourceId  \
# 0     59.12047750994818  25.908444438771234           1551     HITS
# 1  '-61.403450159145564  23.216853270477444           1551     HITS
# 2   '-13.05301459420173  12.248511871579167           1551     HITS
# 3     45.67693500913087  1.5066906332843488           1551     HITS
# 4     60.72425312534558  1.7156498168935792           1551     HITS
# 5      78.9267255469703  15.232316951274957           1551     HITS
# 6     61.20607065216477   4.339086471983462           1551     HITS
# 7   '-55.46266761567982   11.22952024788018           1551     HITS
# 8   '-75.05231625580653   22.68346720975374           1551     HITS
# 9     '-84.300380457189  11.991606166495325           1551     HITS
#
#    SourceNativeMarkerId                       SourceType   Speed  \
# 0                     8  MA_SOURCE_TYPE_OFFICIAL_SCORING 123.439
# 1                   201  MA_SOURCE_TYPE_OFFICIAL_SCORING  81.433
# 2                    10  MA_SOURCE_TYPE_OFFICIAL_SCORING 108.318
# 3                    11  MA_SOURCE_TYPE_OFFICIAL_SCORING 102.541
# 4                    12  MA_SOURCE_TYPE_OFFICIAL_SCORING  62.167
# 5                    13  MA_SOURCE_TYPE_OFFICIAL_SCORING  86.298
# 6                    14  MA_SOURCE_TYPE_OFFICIAL_SCORING 114.777
# 7                    18  MA_SOURCE_TYPE_OFFICIAL_SCORING  93.027
# 8                    19  MA_SOURCE_TYPE_OFFICIAL_SCORING  98.611
# 9                    20  MA_SOURCE_TYPE_OFFICIAL_SCORING 110.327
#
#    TotalClockSec            ttl           UpdateType  VisitorScore  \
# 0             35 1683583981.057  MA_UPDATE_TYPE_EDIT             0
# 1             42 1683578920.176  MA_UPDATE_TYPE_EDIT             0
# 2             97 1683583981.057  MA_UPDATE_TYPE_EDIT             0
# 3            133 1683573930.241  MA_UPDATE_TYPE_EDIT             0
# 4            178 1683583981.057  MA_UPDATE_TYPE_EDIT             0
# 5            215 1683583981.057  MA_UPDATE_TYPE_EDIT             0
# 6            225 1683583981.057  MA_UPDATE_TYPE_EDIT             0
# 7            284 1683583981.057  MA_UPDATE_TYPE_EDIT             0
# 8            307 1683573930.241  MA_UPDATE_TYPE_EDIT             0
# 9            322 1683583981.057  MA_UPDATE_TYPE_EDIT             0
#
#    WasAwarded WasBlocked  WasEmptyNet  WasGoal  WasOnTargetToGoal  WasOwnGoal  \
# 0       False        NaN        False    False               True       False
# 1       False        NaN        False    False              False       False
# 2       False        NaN        False    False              False       False
# 3       False        NaN        False    False              False       False
# 4       False        NaN        False    False              False       False
# 5       False        NaN        False    False              False       False
# 6       False        NaN        False    False              False       False
# 7       False        NaN        False    False              False       False
# 8       False        NaN        False    False              False       False
# 9       False        NaN        False    False               True       False
#
#    WasPenaltyShot WasSaved WasTipped  \
# 0           False     True       NaN
# 1           False      NaN     False
# 2           False      NaN     False
# 3           False      NaN     False
# 4           False      NaN       NaN
# 5           False      NaN     False
# 6           False      NaN     False
# 7           False      NaN       NaN
# 8           False      NaN     False
# 9           False     True       NaN
#
#                                  shot_outcome_coords
# 0  {'puck_x': Decimal('89'), 'puck_y': Decimal('0...
# 1  {'puck_x': Decimal('89'), 'puck_y': Decimal('9...
# 2  {'puck_x': Decimal('89'), 'puck_y': Decimal('7...
# 3  {'puck_x': Decimal('89'), 'puck_y': Decimal('0...
# 4  {'puck_x': Decimal('89'), 'puck_y': Decimal('8...
# 5  {'puck_x': Decimal('89'), 'puck_y': Decimal('0...
# 6  {'puck_x': Decimal('89'), 'puck_y': Decimal('0...
# 7  {'puck_x': Decimal('89'), 'puck_y': Decimal('2...
# 8  {'puck_x': Decimal('89'), 'puck_y': Decimal('1...
# 9  {'puck_x': Decimal('89'), 'puck_y': Decimal('1...

# %%
shot_events_df.iloc[0]['shot_outcome_coords']
# Out:
# "{'puck_x': Decimal('89'), 'puck_y': Decimal('0.5495137543841562'), 'puck_z': Decimal('4.255482757311791')}"

# %%
def remove_decimal(val):
    if isinstance(val, Decimal):
        return float(val)
    elif isinstance(val, dict):
        return {k: remove_decimal(v) for k, v in val.items()}
    elif isinstance(val, list):
        return [remove_decimal(v) for v in val]
    else:
        return val
    
shot_events_df['shot_outcome_coords'] = shot_events_df['shot_outcome_coords'].apply(lambda x: remove_decimal(eval(x)))

# %% [markdown]
# ### Sniper Ability - Potential All-Star Application

# %% [markdown]
# In the case of players shooting on an empty net (or net with targets) we may change the code so that the calculation is being made once the puck has crossed the goal-line.

# %%
def distance_to_nearest_bar(shot_events_df):
    
    distances = []
    
    for index,row in shot_events_df.iterrows():
        
        # Puck coords
        puck_x = row['shot_outcome_coords']['puck_x']
        puck_y = row['shot_outcome_coords']['puck_y']
        puck_z = row['shot_outcome_coords']['puck_z']        
    
        # Check if the puck's y coordinate is within the bounds of the goal frame
        if puck_y < -3 or puck_y > 3 or puck_z > 4:
            distances.append(np.nan)
            continue
        
        # Exclude cases where players may be purposely shooting five-hole, below blocker or glove 
        # These are strategic shot placements but we can't measure these cases
        if puck_y > -2 and puck_y < 2 and puck_z < 3:
            distances.append(np.nan)
            continue
            
        # Post
        bar1 = -3
        # Post
        bar2 = 3
        # Cross-bar
        bar3 = 4

        # Calculate the distances from the puck to each of the three bars
        dist1 = np.abs(puck_y - bar1)
        dist2 = np.abs(puck_y - bar2)
        dist3 = np.abs(puck_z - bar3)
        
        # Add to list
        distances.append(min(dist1, dist2, dist3))
        
    # Add to df
    shot_events_df['distance_to_nearest_bar'] = distances

    
    return shot_events_df

# %%
shot_events_df = distance_to_nearest_bar(shot_events_df)

# %%
shot_events_df
# Out:
#      Unnamed: 0  index                                EventId        ShotUTC  \
# 0             0      0  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637075.918
# 1             1      1  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637084.382
# 2             2      2  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637139.534
# 3             3      3  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637201.599
# 4             4      4  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637245.739
# 5             5      5  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637283.883
# 6             6      6  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637293.211
# 7             7      7  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637424.612
# 8             8      8  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637449.380
# 9             9      9  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637462.436
# 10           10     10  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637524.996
# 11           11     11  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637593.493
# 12           12     12  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637668.661
# 13           13     13  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682637923.686
# 14           14     14  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682638000.019
# 15           15     15  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682638348.337
# 16           16     16  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682638413.473
# 17           17     17  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682638415.537
# 18           18     18  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682638701.843
# 19           19     19  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682638884.316
# 20           20     20  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682638956.940
# 21           21     21  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682639019.212
# 22           22     22  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682639043.848
# 23           23     23  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682639166.329
# 24           24     24  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682639269.834
# 25           25     25  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682639271.706
# 26           26     26  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682639284.858
# 27           27     27  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682639289.690
# 28           28     28  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682639318.666
# 29           29     29  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682639362.314
# 30           30     30  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682639395.626
# 31           31     31  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682639410.694
# 32           32     32  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682639425.075
# 33           33     33  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682640610.543
# 34           34     34  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682640705.108
# 35           35     35  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682640732.244
# 36           36     36  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682640750.884
# 37           37     37  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682640793.364
# 38           38     38  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682640867.837
# 39           39     39  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682640888.317
# 40           40     40  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682640938.189
# 41           41     41  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682641064.526
# 42           42     42  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682641070.030
# 43           43     43  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682641084.862
# 44           44     44  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682641450.456
# 45           45     45  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682641462.840
# 46           46     46  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682641514.264
# 47           47     47  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682641573.396
# 48           48     48  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682641948.722
# 49           49     49  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682642056.263
# 50           50     50  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682642266.520
# 51           51     51  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682642385.897
# 52           52     52  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682642402.393
# 53           53     53  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682642420.393
# 54           54     54  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682642429.049
# 55           55     55  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682642436.329
# 56           56     56  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682642443.433
# 57           57     57  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682642613.622
# 58           58     58  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682642624.758
# 59           59     59  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682644059.606
# 60           60     60  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682644083.110
# 61           61     61  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682644084.310
# 62           62     62  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682644093.078
# 63           63     63  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682644098.854
# 64           64     64  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682644137.830
# 65           65     65  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682644330.575
# 66           66     66  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682644420.611
# 67           67     67  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682644448.024
# 68           68     68  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682644604.617
# 69           69     69  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682644680.901
# 70           70     70  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682644926.090
# 71           71     71  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682645025.475
# 72           72     72  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682645036.803
# 73           73     73  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682645084.131
# 74           74     74  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682645167.111
# 75           75     75  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682645310.124
# 76           76     76  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682645342.412
# 77           77     77  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682645610.074
# 78           78     78  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682645620.906
# 79           79     79  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682645799.855
# 80           80     80  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682645800.399
# 81           81     81  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682645954.880
# 82           82     82  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682646087.216
# 83           83     83  HOCKEY_NHL_2023_04_27_TBL@TOR_HITS125 1682646137.165
# 84           84     84  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683593240.747
# 85           85     85  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683593401.147
# 86           86     86  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683593631.147
# 87           87     87  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683593696.571
# 88           88     88  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683593698.075
# 89           89     89  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683593720.251
# 90           90     90  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683593739.019
# 91           91     91  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683594009.267
# 92           92     92  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683594012.259
# 93           93     93  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683594019.191
# 94           94     94  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683594027.575
# 95           95     95  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683594039.819
# 96           96     96  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683594245.715
# 97           97     97  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683594248.171
# 98           98     98  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683594254.571
# 99           99     99  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683594255.775
# 100         100    100  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683594407.520
# 101         101    101  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683594442.896
# 102         102    102  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683594555.296
# 103         103    103  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683594729.312
# 104         104    104  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683594914.240
# 105         105    105  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683595073.984
# 106         106    106  HOCKEY_NHL_2023_05_08_VGK@EDM_HITS243 1683595130.400
#
#       Angle   Assist1Zone Assist2Location_X Assist2Location_Y   Assist2Zone  \
# 0   120.473           NaN               NaN               NaN           NaN
# 1   139.297           NaN               NaN               NaN           NaN
# 2    49.826           NaN               NaN               NaN           NaN
# 3   138.615           NaN               NaN               NaN           NaN
# 4   167.427           NaN               NaN               NaN           NaN
# 5   156.414           NaN               NaN               NaN           NaN
# 6   128.160           NaN               NaN               NaN           NaN
# 7    60.234           NaN               NaN               NaN           NaN
# 8   138.553           NaN               NaN               NaN           NaN
# 9   140.241           NaN               NaN               NaN           NaN
# 10   75.507  ZONE_OFFENSE              '-97                18  ZONE_OFFENSE
# 11   60.143           NaN               NaN               NaN           NaN
# 12   82.776           NaN               NaN               NaN           NaN
# 13  111.998           NaN               NaN               NaN           NaN
# 14   79.060           NaN               NaN               NaN           NaN
# 15  175.181           NaN               NaN               NaN           NaN
# 16   97.474           NaN               NaN               NaN           NaN
# 17  148.449           NaN               NaN               NaN           NaN
# 18  105.882           NaN               NaN               NaN           NaN
# 19   88.515           NaN               NaN               NaN           NaN
# 20   61.050           NaN               NaN               NaN           NaN
# 21  131.589           NaN               NaN               NaN           NaN
# 22  123.318           NaN               NaN               NaN           NaN
# 23  105.437           NaN               NaN               NaN           NaN
# 24   49.494           NaN               NaN               NaN           NaN
# 25  135.262           NaN               NaN               NaN           NaN
# 26  136.523           NaN               NaN               NaN           NaN
# 27   51.257           NaN               NaN               NaN           NaN
# 28   63.051           NaN               NaN               NaN           NaN
# 29    4.579           NaN               NaN               NaN           NaN
# 30   69.621           NaN               NaN               NaN           NaN
# 31  129.552           NaN               NaN               NaN           NaN
# 32  126.752           NaN               NaN               NaN           NaN
# 33  121.912           NaN               NaN               NaN           NaN
# 34   78.025           NaN               NaN               NaN           NaN
# 35   69.606           NaN               NaN               NaN           NaN
# 36   85.425           NaN               NaN               NaN           NaN
# 37  135.206           NaN               NaN               NaN           NaN
# 38   86.916           NaN               NaN               NaN           NaN
# 39   44.625           NaN               NaN               NaN           NaN
# 40   18.944  ZONE_DEFENSE                50              '-37  ZONE_DEFENSE
# 41  147.700           NaN               NaN               NaN           NaN
# 42   98.603           NaN               NaN               NaN           NaN
# 43   52.961           NaN               NaN               NaN           NaN
# 44  144.712           NaN               NaN               NaN           NaN
# 45   46.487           NaN               NaN               NaN           NaN
# 46  164.155           NaN               NaN               NaN           NaN
# 47  119.257           NaN               NaN               NaN           NaN
# 48  126.479           NaN               NaN               NaN           NaN
# 49  137.782           NaN               NaN               NaN           NaN
# 50  110.076           NaN               NaN               NaN           NaN
# 51  118.975           NaN               NaN               NaN           NaN
# 52  143.407           NaN               NaN               NaN           NaN
# 53   63.731           NaN               NaN               NaN           NaN
# 54  146.570           NaN               NaN               NaN           NaN
# 55   85.763           NaN               NaN               NaN           NaN
# 56   68.578           NaN               NaN               NaN           NaN
# 57  153.281           NaN               NaN               NaN           NaN
# 58  154.709           NaN               NaN               NaN           NaN
# 59  112.885           NaN               NaN               NaN           NaN
# 60   82.507           NaN               NaN               NaN           NaN
# 61   87.275           NaN               NaN               NaN           NaN
# 62   96.439           NaN               NaN               NaN           NaN
# 63  101.229           NaN               NaN               NaN           NaN
# 64   15.340           NaN               NaN               NaN           NaN
# 65   24.271           NaN               NaN               NaN           NaN
# 66  136.598           NaN               NaN               NaN           NaN
# 67  170.101           NaN               NaN               NaN           NaN
# 68   34.552           NaN               NaN               NaN           NaN
# 69   77.828           NaN               NaN               NaN           NaN
# 70   39.277           NaN               NaN               NaN           NaN
# 71   61.155           NaN               NaN               NaN           NaN
# 72    3.135           NaN               NaN               NaN           NaN
# 73   77.101           NaN               NaN               NaN           NaN
# 74   53.256           NaN               NaN               NaN           NaN
# 75   41.828           NaN               NaN               NaN           NaN
# 76   95.392           NaN               NaN               NaN           NaN
# 77  103.302           NaN               NaN               NaN           NaN
# 78   68.317           NaN               NaN               NaN           NaN
# 79   73.183           NaN               NaN               NaN           NaN
# 80   89.494  ZONE_OFFENSE              '-36              '-18  ZONE_OFFENSE
# 81   35.700           NaN               NaN               NaN           NaN
# 82  142.595           NaN               NaN               NaN           NaN
# 83  130.421           NaN               NaN               NaN           NaN
# 84  179.182  ZONE_OFFENSE              '-38                39  ZONE_DEFENSE
# 85   66.599           NaN               NaN               NaN           NaN
# 86  164.214           NaN               NaN               NaN           NaN
# 87  162.884           NaN               NaN               NaN           NaN
# 88  119.815           NaN               NaN               NaN           NaN
# 89  116.144           NaN               NaN               NaN           NaN
# 90   48.890           NaN               NaN               NaN           NaN
# 91   34.349           NaN               NaN               NaN           NaN
# 92  151.911           NaN               NaN               NaN           NaN
# 93  123.407           NaN               NaN               NaN           NaN
# 94  127.089           NaN               NaN               NaN           NaN
# 95   51.569           NaN               NaN               NaN           NaN
# 96  120.172           NaN               NaN               NaN           NaN
# 97   41.683           NaN               NaN               NaN           NaN
# 98  127.058           NaN               NaN               NaN           NaN
# 99   54.199           NaN               NaN               NaN           NaN
# 100  82.673           NaN               NaN               NaN           NaN
# 101  50.164           NaN               NaN               NaN           NaN
# 102  81.215           NaN               NaN               NaN           NaN
# 103 102.967           NaN               NaN               NaN           NaN
# 104 161.509           NaN               NaN               NaN           NaN
# 105  55.620           NaN               NaN               NaN           NaN
# 106 167.613           NaN               NaN               NaN           NaN
#
#     AssistLocation_X AssistLocation_Y  Ballorpuck BlockerLocation_X  \
# 0                NaN              NaN           1               NaN
# 1                NaN              NaN           1              '-65
# 2                NaN              NaN           1                50
# 3                NaN              NaN           1                49
# 4                NaN              NaN           1               NaN
# 5                NaN              NaN           1               NaN
# 6                NaN              NaN           1               NaN
# 7                NaN              NaN           1               NaN
# 8                NaN              NaN           1              '-63
# 9                NaN              NaN           1               NaN
# 10              '-75                7           1               NaN
# 11               NaN              NaN           1               NaN
# 12               NaN              NaN           1              '-59
# 13               NaN              NaN           1               NaN
# 14               NaN              NaN           1               NaN
# 15               NaN              NaN           1                87
# 16               NaN              NaN           1                61
# 17               NaN              NaN           1               NaN
# 18               NaN              NaN           1               NaN
# 19               NaN              NaN           1               NaN
# 20               NaN              NaN           1               NaN
# 21               NaN              NaN           1               NaN
# 22               NaN              NaN           1               NaN
# 23               NaN              NaN           1                73
# 24               NaN              NaN           1               NaN
# 25               NaN              NaN           1                81
# 26               NaN              NaN           1                53
# 27               NaN              NaN           1               NaN
# 28               NaN              NaN           1               NaN
# 29               NaN              NaN           1               NaN
# 30               NaN              NaN           1               NaN
# 31               NaN              NaN           1               NaN
# 32               NaN              NaN           1                76
# 33               NaN              NaN           1               NaN
# 34               NaN              NaN           1               NaN
# 35               NaN              NaN           1               NaN
# 36               NaN              NaN           1                69
# 37               NaN              NaN           1               NaN
# 38               NaN              NaN           1               NaN
# 39               NaN              NaN           1               NaN
# 40                30               35           1               NaN
# 41               NaN              NaN           1               NaN
# 42               NaN              NaN           1               NaN
# 43               NaN              NaN           1              '-72
# 44               NaN              NaN           1               NaN
# 45               NaN              NaN           1               NaN
# 46               NaN              NaN           1               NaN
# 47               NaN              NaN           1               NaN
# 48               NaN              NaN           1               NaN
# 49               NaN              NaN           1              '-67
# 50               NaN              NaN           1               NaN
# 51               NaN              NaN           1               NaN
# 52               NaN              NaN           1               NaN
# 53               NaN              NaN           1              '-58
# 54               NaN              NaN           1               NaN
# 55               NaN              NaN           1               NaN
# 56               NaN              NaN           1               NaN
# 57               NaN              NaN           1               NaN
# 58               NaN              NaN           1               NaN
# 59               NaN              NaN           1               NaN
# 60               NaN              NaN           1               NaN
# 61               NaN              NaN           1              '-83
# 62               NaN              NaN           1               NaN
# 63               NaN              NaN           1               NaN
# 64               NaN              NaN           1               NaN
# 65               NaN              NaN           1               NaN
# 66               NaN              NaN           1               NaN
# 67               NaN              NaN           1                82
# 68               NaN              NaN           1               NaN
# 69               NaN              NaN           1               NaN
# 70               NaN              NaN           1               NaN
# 71               NaN              NaN           1               NaN
# 72               NaN              NaN           1               NaN
# 73               NaN              NaN           1                71
# 74               NaN              NaN           1               NaN
# 75               NaN              NaN           1               NaN
# 76               NaN              NaN           1               NaN
# 77               NaN              NaN           1               NaN
# 78               NaN              NaN           1               NaN
# 79               NaN              NaN           1               NaN
# 80              '-84              '-1           1               NaN
# 81               NaN              NaN           1              '-79
# 82               NaN              NaN           1               NaN
# 83               NaN              NaN           1              '-70
# 84                87             '-27           1               NaN
# 85               NaN              NaN           1               NaN
# 86               NaN              NaN           1                67
# 87               NaN              NaN           1               NaN
# 88               NaN              NaN           1               NaN
# 89               NaN              NaN           1               NaN
# 90               NaN              NaN           1               NaN
# 91               NaN              NaN           1               NaN
# 92               NaN              NaN           1               NaN
# 93               NaN              NaN           1               NaN
# 94               NaN              NaN           1               NaN
# 95               NaN              NaN           1               NaN
# 96               NaN              NaN           1               NaN
# 97               NaN              NaN           1               NaN
# 98               NaN              NaN           1               NaN
# 99               NaN              NaN           1                82
# 100              NaN              NaN           1               NaN
# 101              NaN              NaN           1               NaN
# 102              NaN              NaN           1               NaN
# 103              NaN              NaN           1               NaN
# 104              NaN              NaN           1               NaN
# 105              NaN              NaN           1               NaN
# 106              NaN              NaN           1               NaN
#
#     BlockerLocation_Y   BlockerZone  ClockMinutes  ClockSeconds  ClockTenths  \
# 0                 NaN           NaN            19            25            0
# 1                  23  ZONE_DEFENSE            19            18            0
# 2                   6  ZONE_DEFENSE            18            23            0
# 3                '-28  ZONE_DEFENSE            17            47            0
# 4                 NaN           NaN            17             2            0
# 5                 NaN           NaN            16            25            0
# 6                 NaN           NaN            16            15            0
# 7                 NaN           NaN            15            16            0
# 8                  19  ZONE_DEFENSE            14            53            0
# 9                 NaN           NaN            14            38            0
# 10                NaN           NaN            14            14            0
# 11                NaN           NaN            13            48            0
# 12                '-3  ZONE_DEFENSE            13            15            0
# 13                NaN           NaN            12             1            0
# 14                NaN           NaN            10            43            0
# 15                '-5  ZONE_DEFENSE             8            30            0
# 16               '-15  ZONE_DEFENSE             8             5            0
# 17                NaN           NaN             8             1            0
# 18                NaN           NaN             5            24            0
# 19                NaN           NaN             5             4            0
# 20                NaN           NaN             3            51            0
# 21                NaN           NaN             3            34            0
# 22                NaN           NaN             3             8            0
# 23               '-13  ZONE_DEFENSE             2            15            0
# 24                NaN           NaN             2             3            0
# 25                '-2  ZONE_DEFENSE             2             2            0
# 26                '-9  ZONE_DEFENSE             1            48            0
# 27                NaN           NaN             1            44            0
# 28                NaN           NaN             1            14            0
# 29                NaN           NaN             1             5            0
# 30                NaN           NaN             0            36            0
# 31                NaN           NaN             0            20            0
# 32                '-9  ZONE_DEFENSE             0             5            0
# 33                NaN           NaN            19            22            0
# 34                NaN           NaN            18            23            0
# 35                NaN           NaN            17            54            0
# 36                '-8  ZONE_DEFENSE            17            39            0
# 37                NaN           NaN            17            25            0
# 38                NaN           NaN            16            45            0
# 39                NaN           NaN            16            25            0
# 40                NaN           NaN            15            37            0
# 41                NaN           NaN            14            31            0
# 42                NaN           NaN            14            25            0
# 43                NaN  ZONE_DEFENSE            14            13            0
# 44                NaN           NaN            12             2            0
# 45                NaN           NaN            11            50            0
# 46                NaN           NaN            10            58            0
# 47                NaN           NaN            10             4            0
# 48                NaN           NaN             7            32            0
# 49                 14  ZONE_DEFENSE             6            18            0
# 50                NaN           NaN             5            29            0
# 51                NaN           NaN             4            17            0
# 52                NaN           NaN             4             1            0
# 53               '-24  ZONE_DEFENSE             3            42            0
# 54                NaN           NaN             3            33            0
# 55                NaN           NaN             3            27            0
# 56                NaN           NaN             3            18            0
# 57                NaN           NaN             2             6            0
# 58                NaN           NaN             2             9            0
# 59                NaN           NaN            19            39            0
# 60                NaN           NaN            19            17            0
# 61                  1  ZONE_DEFENSE            19            15            0
# 62                NaN           NaN            19             6            0
# 63                NaN           NaN            19            59            0
# 64                NaN           NaN            18            20            0
# 65                NaN           NaN            16            19            0
# 66                NaN           NaN            14            49            0
# 67               '-20  ZONE_DEFENSE            14            22            0
# 68                NaN           NaN            13             5            0
# 69                NaN           NaN            11            47            0
# 70                NaN           NaN            10            15            0
# 71                NaN           NaN             9             5            0
# 72                NaN           NaN             8            54            0
# 73                NaN  ZONE_DEFENSE             8             8            0
# 74                NaN           NaN             7            37            0
# 75                NaN           NaN             5            41            0
# 76                NaN           NaN             5            31            0
# 77                NaN           NaN             4            16            0
# 78                NaN           NaN             4             2            0
# 79                NaN           NaN             3            34            0
# 80                NaN           NaN             3            34            0
# 81                '-3  ZONE_DEFENSE             2            47            0
# 82                NaN           NaN             1            20            0
# 83                 15  ZONE_DEFENSE             0            29            0
# 84                NaN           NaN            17            15            0
# 85                NaN           NaN            15            20            0
# 86                  2  ZONE_DEFENSE            12            49            0
# 87                NaN           NaN            11            42            0
# 88                NaN           NaN            11            41            0
# 89                NaN           NaN            11            20            0
# 90                NaN           NaN            11             0            0
# 91                NaN           NaN             9             5            0
# 92                NaN           NaN             9             2            0
# 93                NaN           NaN             8            59            0
# 94                NaN           NaN             8            50            0
# 95                NaN           NaN             8            38            0
# 96                NaN           NaN             8            28            0
# 97                NaN           NaN             8            26            0
# 98                NaN           NaN             8            21            0
# 99                  7  ZONE_DEFENSE             8            20            0
# 100               NaN           NaN             8            13            0
# 101               NaN           NaN             8             4            0
# 102               NaN           NaN             6            48            0
# 103               NaN           NaN             4            32            0
# 104               NaN           NaN             3            53            0
# 105               NaN           NaN             2            21            0
# 106               NaN           NaN             2             1            0
#
#      ClosestDefender  ClosestDefenderDistance  Confidence  \
# 0              10044                    7.661         100
# 1              14048                    7.540         100
# 2              10052                   13.074         100
# 3              10052                   11.147         100
# 4              10055                    9.588         100
# 5              10002                    6.737         100
# 6              10023                   25.969         100
# 7              10028                   20.052         100
# 8              14048                    7.148         100
# 9              14077                   17.179         100
# 10             14023                   13.503         100
# 11             10015                   10.068         100
# 12             14043                   12.397         100
# 13             14014                   15.787         100
# 14             10022                    8.708         100
# 15             10044                    8.188         100
# 16             10064                    5.177         100
# 17             10078                    0.448         100
# 18             14048                    6.322         100
# 19             14028                    4.892         100
# 20             14038                   11.085         100
# 21             14043                   27.080         100
# 22             14071                    4.435         100
# 23             10055                    3.226         100
# 24             10016                   26.110         100
# 25             10055                    5.981         100
# 26             10016                   12.090         100
# 27             10078                   12.297         100
# 28             10052                    7.204         100
# 29             10055                    6.871         100
# 30             10064                    7.335         100
# 31             10016                   12.004         100
# 32             10016                    7.627         100
# 33             10044                    6.728         100
# 34             14048                   10.367         100
# 35             14086                    6.245         100
# 36             14086                   28.564         100
# 37             14021                   16.731         100
# 38             14071                    5.378         100
# 39             10044                   10.287         100
# 40             10003                    8.721         100
# 41             10016                    9.748         100
# 42             10016                   16.460         100
# 43             10022                   22.835         100
# 44             10078                    4.556         100
# 45             10034                    7.513         100
# 46             14077                   10.106         100
# 47             10064                    7.412         100
# 48             14010                   19.669         100
# 49             10023                   17.633         100
# 50             10088                    7.603         100
# 51             10022                   10.719         100
# 52             10016                    9.805         100
# 53             10078                    4.724         100
# 54             10078                    9.898         100
# 55             10016                    7.851         100
# 56             10064                   16.688         100
# 57             14098                    8.958         100
# 58             14043                   16.116         100
# 59             10044                    4.591         100
# 60             14077                    7.098         100
# 61             14077                    7.490         100
# 62             10044                    5.577         100
# 63             10091                   12.286         100
# 64             10078                    6.104         100
# 65             14014                   11.583         100
# 66             14091                   17.042         100
# 67             10044                    5.573         100
# 68             10088                   13.509         100
# 69             10023                   10.170         100
# 70             14077                    8.864         100
# 71             14041                    7.626         100
# 72             14043                    9.009         100
# 73             10028                    9.074         100
# 74             14023                   15.905         100
# 75             10091                   14.351         100
# 76             10022                    6.528         100
# 77             14038                   14.327         100
# 78             10044                    6.173         100
# 79             14077                    6.837         100
# 80             14077                    6.518         100
# 81             14021                   18.807         100
# 82             14098                    8.516         100
# 83             14098                   13.099         100
# 84             54022                   10.979         100
# 85             22072                    5.354         100
# 86             54009                   13.287         100
# 87             54021                    5.879         100
# 88             54061                    3.343         100
# 89             54021                   15.951         100
# 90             54020                   13.821         100
# 91             22073                   11.535         100
# 92             22073                    7.615         100
# 93             22027                   31.344         100
# 94             54002                   12.058         100
# 95             22005                    4.641         100
# 96             22002                    8.185         100
# 97             22097                   11.685         100
# 98             54007                    8.520         100
# 99             54009                   18.131         100
# 100            54055                   19.514         100
# 101            54071                   12.491         100
# 102            22002                    4.908         100
# 103            22005                    9.678         100
# 104            22014                    7.103         100
# 105            54023                    7.953         100
# 106            22014                    5.905         100
#
#                                             Descriptor  Distance  \
# 0    "HITS : E#8 19:25 - Shot. ONGOAL. V#17, Killorn."        40
# 1    "HITS : E#201 19:18 - Shot. VBLOCKED. H#88, Ny...        33
# 2    "HITS : E#10 18:23 - Shot. HBLOCKED. V#98, Ser...        39
# 3    "HITS : E#11 17:47 - Shot. HBLOCKED. V#28, Cole."        48
# 4    "HITS : E#12 17:02 - Shot. ONGOAL. V#86, Kuche...        39
# 5    "HITS : E#13 16:25 - Shot. MISSED. V#14, Maroon."        18
# 6    "HITS : E#14 16:15 - Shot. ONGOAL. V#24, Bogos...        66
# 7    "HITS : E#18 15:16 - Shot. ONGOAL. V#86, Kuche...        58
# 8    "HITS : E#19 14:53 - Shot. VBLOCKED. H#28, Laf...        32
# 9    "HITS : E#20 14:38 - Shot. ONGOAL. H#12, Aston...        47
# 10   "HITS : E#22 14:14 - Shot (Goal!). H#44, Riell...        39
# 11    "HITS : E#23 13:48 - Shot. ONGOAL. V#38, Hagel."         9
# 12   "HITS : E#25 13:15 - Shot. VBLOCKED. H#78, Bro...        30
# 13      "HITS : E#27 12:01 - Shot. ONGOAL. H#3, Holl."        45
# 14     "HITS : E#28 10:43 - Shot. MISSED. V#28, Cole."        62
# 15   "HITS : E#33  8:30 - Shot. HBLOCKED. V#79, Col...         5
# 16   "HITS : E#34  8:05 - Shot. HBLOCKED. V#43, Rad...        31
# 17   "HITS : E#37  8:01 - Shot. ONGOAL. V#91, Stamk...        18
# 18   "HITS : E#38  5:24 - Shot. ONGOAL. H#34, Matth...        32
# 19   "HITS : E#39  5:04 - Shot. ONGOAL. H#90, O'Rei...        24
# 20   "HITS : E#40  3:51 - Shot. ONGOAL. H#19, Jarnk...        18
# 21   "HITS : E#43  3:34 - Shot. MISSED. H#34, Matth...        41
# 22   "HITS : E#45  3:08 - Shot. ONGOAL. H#88, Nylan...        13
# 23   "HITS : E#46  2:15 - Shot. HBLOCKED. V#24, Bog...        20
# 24   "HITS : E#47  2:03 - Shot. ONGOAL. V#98, Serga...        62
# 25   "HITS : E#48  2:02 - Shot. HBLOCKED. V#21, Poi...         8
# 26   "HITS : E#49  1:48 - Shot. HBLOCKED. V#98, Ser...        37
# 27   "HITS : E#50  1:44 - Shot. ONGOAL. V#91, Stamk...        42
# 28   "HITS : E#301  1:14 - Shot. ONGOAL. V#91, Stam...        61
# 29   "HITS : E#304  1:05 - Shot. ONGOAL. V#21, Point."         8
# 30   "HITS : E#305  0:36 - Shot. ONGOAL. V#91, Stam...        37
# 31   "HITS : E#306  0:20 - Shot. ONGOAL. V#86, Kuch...        38
# 32   "HITS : E#307  0:05 - Shot. HBLOCKED. V#86, Ku...        15
# 33   "HITS : E#313 19:22 - Shot. ONGOAL. V#77, Hedm...        32
# 34   "HITS : E#314 18:23 - Shot. ONGOAL. H#91, Tava...        14
# 35   "HITS : E#316 17:54 - Shot. MISSED. H#91, Tava...        51
# 36   "HITS : E#317 17:39 - Shot. VBLOCKED. H#78, Br...        21
# 37   "HITS : E#318 17:25 - Shot. ONGOAL. H#2, Schenn."        49
# 38   "HITS : E#319 16:45 - Shot. MISSED. H#44, Riel...        35
# 39   "HITS : E#320 16:25 - Shot. MISSED. V#71, Cire...        32
# 40   "HITS : E#321 15:37 - Shot (Goal!). V#23, Eyss...        14
# 41   "HITS : E#322 14:31 - Shot. ONGOAL. V#91, Stam...        39
# 42   "HITS : E#323 14:25 - Shot. MISSED. V#43, Radd...        37
# 43   "HITS : E#324 14:13 - Shot. HBLOCKED. V#86, Ku...        17
# 44   "HITS : E#325 12:02 - Shot. ONGOAL. V#71, Cire...        32
# 45   "HITS : E#327 11:50 - Shot. ONGOAL. V#38, Hagel."        44
# 46     "HITS : E#330 10:58 - Shot. ONGOAL. H#3, Holl."        30
# 47   "HITS : E#332 10:04 - Shot. MISSED. V#24, Bogo...        51
# 48   "HITS : E#334  7:32 - Shot. MISSED. H#22, McCa...        45
# 49   "HITS : E#335  6:18 - Shot. HBLOCKED. V#43, Ra...        26
# 50   "HITS : E#337  5:29 - Shot. ONGOAL. V#48, Perb...        54
# 51   "HITS : E#339  4:17 - Shot. MISSED. V#21, Point."        20
# 52   "HITS : E#340  4:01 - Shot. ONGOAL. V#21, Point."         6
# 53   "HITS : E#341  3:42 - Shot. HBLOCKED. V#86, Ku...        39
# 54   "HITS : E#342  3:33 - Shot. ONGOAL. V#86, Kuch...        29
# 55   "HITS : E#211  3:27 - Shot. MISSED. V#98, Serg...        59
# 56   "HITS : E#343  3:18 - Shot. ONGOAL. V#98, Serg...        65
# 57   "HITS : E#346  2:06 - Shot. ONGOAL. H#88, Nyla...         8
# 58   "HITS : E#345  2:09 - Shot. MISSED. H#19, Jarn...         8
# 59   "HITS : E#652 19:39 - Shot. ONGOAL. V#38, Hagel."        33
# 60   "HITS : E#214 19:17 - Shot. ONGOAL. H#90, O'Re...        13
# 61   "HITS : E#655 19:15 - Shot. VBLOCKED. H#91, Ta...         6
# 62   "HITS : E#656 19:06 - Shot. ONGOAL. V#17, Kill...        31
# 63   "HITS : E#657 19:00 - Shot. ONGOAL. V#43, Radd...        30
# 64   "HITS : E#659 18:20 - Shot. ONGOAL. V#71, Cire...        24
# 65   "HITS : E#662 16:19 - Shot. ONGOAL. H#55, Gior...        69
# 66   "HITS : E#663 14:49 - Shot. ONGOAL. H#16, Marn...        16
# 67   "HITS : E#664 14:22 - Shot. HBLOCKED. V#20, Pa...        21
# 68   "HITS : E#666 13:05 - Shot. ONGOAL. V#17, Kill...        23
# 69   "HITS : E#669 11:47 - Shot. ONGOAL. V#91, Stam...        32
# 70   "HITS : E#671 10:15 - Shot. ONGOAL. H#19, Jarn...        21
# 71   "HITS : E#672  9:05 - Shot. ONGOAL. H#78, Brod...        99
# 72   "HITS : E#673  8:54 - Shot. ONGOAL. H#91, Tava...        25
# 73   "HITS : E#674  8:08 - Shot. HBLOCKED. V#20, Pa...        18
# 74   "HITS : E#676  7:37 - Shot. MISSED. H#44, Riel...        56
# 75   "HITS : E#677  5:41 - Shot. ONGOAL. V#77, Hedm...        33
# 76   "HITS : E#678  5:31 - Shot. ONGOAL. V#86, Kuch...        30
# 77   "HITS : E#681  4:16 - Shot. MISSED. H#34, Matt...        38
# 78   "HITS : E#684  4:02 - Shot. MISSED. V#38, Hagel."       103
# 79   "HITS : E#685  3:34 - Shot. ONGOAL. H#91, Tava...         9
# 80   "HITS : E#686  3:34 - Shot (Goal!). H#34, Matt...         7
# 81   "HITS : E#687  2:47 - Shot. VBLOCKED. H#16, Ma...        10
# 82   "HITS : E#689  1:20 - Shot. ONGOAL. H#88, Nyla...        24
# 83   "HITS : E#690  0:29 - Shot. VBLOCKED. H#88, Ny...        24
# 84   "HITS : E#152 17:15 - Shot (Goal!). H#37, Foeg...         5
# 85   "HITS : E#154 15:20 - Shot. ONGOAL. V#81, Marc...         8
# 86   "HITS : E#157 12:49 - Shot. VBLOCKED. H#2, Bou...        22
# 87   "HITS : E#158 11:42 - Shot. ONGOAL. H#73, Desh...        34
# 88   "HITS : E#159 11:41 - Shot. MISSED. H#29, Drai...        17
# 89   "HITS : E#160 11:20 - Shot. MISSED. H#29, Drai...        30
# 90   "HITS : E#162 11:00 - Shot. MISSED. H#2, Bouch...        45
# 91   "HITS : E#163  9:05 - Shot. ONGOAL. V#71, Karl...        25
# 92   "HITS : E#164  9:02 - Shot. ONGOAL. V#22, Amad...        13
# 93   "HITS : E#165  8:59 - Shot. ONGOAL. V#2, White...        60
# 94   "HITS : E#166  8:50 - Shot. ONGOAL. H#37, Foeg...        24
# 95   "HITS : E#167  8:38 - Shot. ONGOAL. V#71, Karl...        20
# 96   "HITS : E#168  8:28 - Shot. ONGOAL. V#9, Eichel."        45
# 97   "HITS : E#169  8:26 - Shot. MISSED. V#49, Barb...        17
# 98   "HITS : E#170  8:21 - Shot. ONGOAL. H#97, McDa...        23
# 99   "HITS : E#171  8:20 - Shot. VBLOCKED. H#91, Ka...         9
# 100  "HITS : E#172  8:13 - Shot. ONGOAL. H#14, Ekho...        53
# 101  "HITS : E#173  8:04 - Shot. ONGOAL. H#29, Drai...        15
# 102  "HITS : E#175  6:48 - Shot. ONGOAL. V#61, Stone."         8
# 103  "HITS : E#179  4:32 - Shot. ONGOAL. V#61, Stone."        13
# 104  "HITS : E#180  3:53 - Shot. ONGOAL. V#9, Eichel."        28
# 105  "HITS : E#181  2:21 - Shot. ONGOAL. H#97, McDa...        31
# 106  "HITS : E#182  2:01 - Shot. ONGOAL. V#19, Smith."         9
#
#             EndUTC    Goalie           GoalieAngle  HomeScore  \
# 0   1682637076.254 10035.000    118.99925709659834          0
# 1   1682637084.993 14088.000    131.13038500795074          0
# 2   1682637139.678 10035.000     82.91321951682266          0
# 3   1682637201.695 10035.000    119.28029777897757          0
# 4   1682637246.267 10035.000    166.32048832335977          0
# 5   1682637284.060 10035.000    168.16551674175412          0
# 6   1682637293.755 10035.000    122.07545243248006          0
# ...
# 59   MA_UPDATE_TYPE_EDIT             2       False        NaN        False
# 60   MA_UPDATE_TYPE_EDIT             2       False        NaN        False
# 61   MA_UPDATE_TYPE_EDIT             2       False        NaN        False
# 62   MA_UPDATE_TYPE_EDIT             2       False        NaN        False
# 63   MA_UPDATE_TYPE_EDIT             2       False        NaN        False
# 64   MA_UPDATE_TYPE_EDIT             2       False        NaN        False
# 65   MA_UPDATE_TYPE_EDIT             2       False        NaN        False
# 66   MA_UPDATE_TYPE_EDIT             2       False        NaN        False
# 67   MA_UPDATE_TYPE_EDIT             2       False        NaN        False
# 68   MA_UPDATE_TYPE_EDIT             2       False        NaN        False
# 69   MA_UPDATE_TYPE_EDIT             2       False        NaN        False
# 70   MA_UPDATE_TYPE_EDIT             2       False        NaN        False
# 71   MA_UPDATE_TYPE_EDIT             2       False        NaN        False
# 72   MA_UPDATE_TYPE_EDIT             2       False        NaN        False
# 73   MA_UPDATE_TYPE_EDIT             2       False       True        False
# 74   MA_UPDATE_TYPE_EDIT             3       False        NaN        False
# 75   MA_UPDATE_TYPE_EDIT             3       False        NaN        False
# 76   MA_UPDATE_TYPE_EDIT             3       False        NaN        False
# 77   MA_UPDATE_TYPE_EDIT             3       False        NaN        False
# 78   MA_UPDATE_TYPE_EDIT             3       False        NaN        False
# 79   MA_UPDATE_TYPE_EDIT             3       False        NaN        False
# 80   MA_UPDATE_TYPE_EDIT             3       False        NaN        False
# 81   MA_UPDATE_TYPE_EDIT             3       False        NaN        False
# 82   MA_UPDATE_TYPE_EDIT             3       False        NaN        False
# 83   MA_UPDATE_TYPE_EDIT             3       False        NaN        False
# 84   MA_UPDATE_TYPE_EDIT             0       False        NaN        False
# 85   MA_UPDATE_TYPE_EDIT             0       False        NaN        False
# 86   MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 87   MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 88   MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 89   MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 90   MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 91   MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 92   MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 93   MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 94   MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 95   MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 96   MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 97   MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 98   MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 99   MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 100  MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 101  MA_UPDATE_TYPE_EDIT             1       False       True        False
# 102  MA_UPDATE_TYPE_EDIT             1       False       True        False
# 103  MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 104  MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 105  MA_UPDATE_TYPE_EDIT             1       False        NaN        False
# 106  MA_UPDATE_TYPE_EDIT             1       False        NaN        False
#
#      WasGoal  WasOnTargetToGoal  WasOwnGoal  WasPenaltyShot WasSaved  \
# 0      False               True       False           False     True
# 1      False              False       False           False      NaN
# 2      False              False       False           False      NaN
# 3      False              False       False           False      NaN
# 4      False              False       False           False      NaN
# 5      False              False       False           False      NaN
# 6      False              False       False           False      NaN
# 7      False              False       False           False      NaN
# 8      False              False       False           False      NaN
# 9      False               True       False           False     True
# 10      True               True       False           False      NaN
# 11     False              False       False           False      NaN
# 12     False              False       False           False      NaN
# 13     False              False       False           False      NaN
# 14     False              False       False           False      NaN
# 15     False               True       False           False     True
# 16     False              False       False           False      NaN
# 17     False               True       False           False      NaN
# 18     False              False       False           False      NaN
# 19     False              False       False           False      NaN
# 20     False               True       False           False     True
# 21     False              False       False           False      NaN
# 22     False              False       False           False      NaN
# 23     False              False       False           False      NaN
# 24     False              False       False           False      NaN
# 25     False              False       False           False      NaN
# 26     False              False       False           False      NaN
# 27     False               True       False           False     True
# 28     False               True       False           False     True
# 29     False              False       False           False      NaN
# 30     False               True       False           False     True
# 31     False              False       False           False      NaN
# 32     False              False       False           False      NaN
# 33     False               True       False           False      NaN
# 34     False              False       False           False      NaN
# 35     False              False       False           False      NaN
# 36     False              False       False           False      NaN
# 37     False               True       False           False     True
# 38     False              False       False           False      NaN
# 39     False              False       False           False      NaN
# 40      True               True       False           False      NaN
# 41     False              False       False           False      NaN
# 42     False              False       False           False      NaN
# 43     False               True       False           False      NaN
# 44     False              False       False           False      NaN
# 45     False              False       False           False      NaN
# 46     False              False       False           False      NaN
# 47     False              False       False           False      NaN
# 48     False              False       False           False      NaN
# 49     False               True       False           False      NaN
# 50     False               True       False           False     True
# 51     False               True       False           False     True
# 52     False              False       False           False      NaN
# 53     False              False       False           False      NaN
# 54     False              False       False           False      NaN
# 55     False              False       False           False      NaN
# 56     False              False       False           False      NaN
# 57     False               True       False           False     True
# 58     False              False       False           False      NaN
# 59     False              False       False           False      NaN
# 60     False               True       False           False     True
# 61     False              False       False           False      NaN
# 62     False              False       False           False      NaN
# 63     False               True       False           False     True
# 64     False              False       False           False      NaN
# 65     False              False       False           False      NaN
# 66     False              False       False           False      NaN
# 67     False              False       False           False      NaN
# 68     False              False       False           False      NaN
# 69     False              False       False           False      NaN
# 70     False               True       False           False     True
# 71     False              False       False           False      NaN
# 72     False              False       False           False      NaN
# 73     False               True       False           False      NaN
# 74     False              False       False           False      NaN
# 75     False               True       False           False     True
# 76     False               True       False           False     True
# 77     False              False       False           False      NaN
# 78     False              False       False           False      NaN
# 79     False               True       False           False     True
# 80      True               True       False           False      NaN
# 81     False              False       False           False      NaN
# 82     False              False       False           False      NaN
# 83     False              False       False           False      NaN
# 84      True              False       False           False      NaN
# 85     False               True       False           False     True
# 86     False              False       False           False      NaN
# 87     False              False       False           False      NaN
# 88     False              False       False           False      NaN
# 89     False               True       False           False     True
# 90     False              False       False           False      NaN
# 91     False               True       False           False     True
# 92     False               True       False           False     True
# 93     False              False       False           False      NaN
# 94     False               True       False           False     True
# 95     False              False       False           False      NaN
# 96     False              False       False           False      NaN
# 97     False              False       False           False      NaN
# 98     False               True       False           False     True
# 99     False              False       False           False      NaN
# 100    False               True       False           False      NaN
# 101    False               True       False           False      NaN
# 102    False               True       False           False      NaN
# 103    False               True       False           False     True
# 104    False               True       False           False      NaN
# 105    False               True       False           False     True
# 106    False              False       False           False      NaN
#
#     WasTipped  distance_to_nearest_bar
# 0         NaN                      NaN
# 1       False                      NaN
# 2       False                      NaN
# 3       False                      NaN
# 4         NaN                      NaN
# 5       False                      NaN
# 6       False                      NaN
# 7         NaN                    0.463
# 8       False                      NaN
# 9         NaN                      NaN
# 10      False                    0.425
# 11        NaN                      NaN
# 12      False                      NaN
# 13        NaN                      NaN
# 14      False                      NaN
# 15        NaN                      NaN
# 16        NaN                      NaN
# 17        NaN                      NaN
# 18        NaN                      NaN
# 19       True                      NaN
# 20      False                    0.533
# 21        NaN                      NaN
# 22        NaN                      NaN
# 23        NaN                      NaN
# 24        NaN                      NaN
# 25        NaN                      NaN
# 26        NaN                      NaN
# 27      False                    0.251
# 28        NaN                      NaN
# 29        NaN                      NaN
# 30        NaN                      NaN
# 31        NaN                    0.343
# 32        NaN                      NaN
# 33        NaN                      NaN
# 34        NaN                      NaN
# 35        NaN                      NaN
# 36      False                    0.434
# 37        NaN                      NaN
# 38        NaN                      NaN
# 39      False                      NaN
# 40      False                      NaN
# 41      False                      NaN
# 42      False                      NaN
# 43      False                      NaN
# 44        NaN                      NaN
# 45      False                      NaN
# 46        NaN                      NaN
# 47      False                      NaN
# 48      False                      NaN
# 49        NaN                      NaN
# 50        NaN                    0.059
# 51        NaN                      NaN
# 52      False                      NaN
# 53      False                      NaN
# 54        NaN                      NaN
# 55      False                      NaN
# 56        NaN                      NaN
# 57        NaN                      NaN
# 58       True                      NaN
# 59        NaN                    0.236
# 60      False                      NaN
# 61      False                      NaN
# 62      False                      NaN
# 63      False                      NaN
# 64        NaN                    0.427
# 65        NaN                      NaN
# 66        NaN                      NaN
# 67      False                      NaN
# 68        NaN                      NaN
# 69        NaN                    0.103
# 70      False                    0.435
# 71      False                      NaN
# 72        NaN                      NaN
# 73      False                      NaN
# 74      False                      NaN
# 75        NaN                      NaN
# 76        NaN                      NaN
# 77      False                      NaN
# 78        NaN                      NaN
# 79        NaN                      NaN
# 80       True                      NaN
# 81        NaN                      NaN
# 82      False                    0.655
# 83        NaN                      NaN
# 84      False                      NaN
# 85      False                      NaN
# 86        NaN                      NaN
# 87        NaN                      NaN
# 88      False                      NaN
# 89      False                    0.098
# 90        NaN                      NaN
# 91        NaN                    0.560
# 92      False                      NaN
# 93        NaN                      NaN
# 94        NaN                      NaN
# 95        NaN                      NaN
# 96      False                      NaN
# 97      False                      NaN
# 98      False                      NaN
# 99        NaN                      NaN
# 100     False                      NaN
# 101     False                      NaN
# 102       NaN                      NaN
# 103       NaN                      NaN
# 104       NaN                      NaN
# 105     False                    0.710
# 106       NaN                      NaN

# %%
def calculate_sniper_ability(shot_events_df):
    
    # Group the dataframe by Shooter and calculate the mean distance to the nearest bar for each player
    avg_distance = shot_events_df.groupby("Shooter")["distance_to_nearest_bar"].mean()
    
    # Find the player with the lowest average distance to the nearest bar
    best_sniper = avg_distance.idxmin()
    
    print(f"{best_sniper} had the greatest sniper ability")
    
    # Return the dictionary of average distances
    return avg_distance.to_dict()

# %%
calculate_sniper_ability(shot_events_df)
# Out:
# 14048 had the greatest sniper ability
# {10002: nan,
#  10003: nan,
#  10012: nan,
#  10016: nan,
#  10019: 0.48383910050588974,
#  10022: nan,
#  10028: nan,
#  10034: nan,
#  10044: 0.425033182969881,
#  10055: nan,
#  10078: 0.43364385342918244,
#  10088: 0.655248628187378,
#  10090: nan,
#  10091: nan,
#  14014: nan,
#  14017: nan,
#  14020: nan,
#  14021: nan,
#  14023: nan,
#  14024: nan,
#  14028: nan,
#  14038: 0.23632656002950458,
#  14043: nan,
#  14048: 0.0593070586741451,
#  14071: 0.42727461418718526,
#  14077: nan,
#  14079: nan,
#  14086: 0.40289002666513163,
#  14091: 0.17690485282748347,
#  14098: nan,
#  22002: nan,
#  22014: nan,
#  22029: 0.09836758421522562,
#  22037: nan,
#  22073: nan,
#  22091: nan,
#  22097: 0.7097946991314075,
#  54002: nan,
#  54009: nan,
#  54019: nan,
#  54022: nan,
#  54049: nan,
#  54061: nan,
#  54071: 0.5604978173849244,
#  54081: nan}

# %%
# Additions

# 1) calculation made only when player is shooting to score .... 
    # in all star game don't need to worry about this on target shooting 
    # during game, check if shot was tipped or if there is a teammate out front
    
# 2) lift restrictions on shot outcome coords for when players are shooting on an open net (all-star game)

# 3) contest idea - sniper ability - similar to target shooting 
    # players shoot the puck 10 times
    # takes average of the calculation over the 10 shots 
    # lowest score is the ultimate sniper
    # bar down is a calculation of zero 
    
# 4) components to calc - check if posts was likely hit
# check velocity angle change at that poont to determine bar down or post in
# rely on granularity of puck between goal line and when it goes into net
