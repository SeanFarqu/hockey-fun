# %% [markdown]
# # PPT High-Sticking Review

# %% [markdown]
# Goals Scored With A High Stick
# High-stick goals are covered in a few different sections of the rule book.
#
# Rule 80 covers high-sticking on goal-scoring plays.  From 80.3:
#
# When an attacking player causes the puck to enter the opponent’s goal by contacting the puck above the height of the crossbar, either directly or deflected off any player or official, the goal shall not be allowed. The determining factor is where the puck makes contact with the stick. If the puck makes contact with the stick at or below the level of the crossbar and enters the goal, this goal shall be allowed.

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as ani
import cv2
import matplotlib.colors as mcolors
import matplotlib.cm as cm
from scipy.signal import butter,filtfilt
import plotly.graph_objects as go
import time
import math
import os


import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)


#signing into the PPT

headers = {
    'accept': '*/*',
    'Content-Type': 'application/json-patch+json',
}

# data = '{ "Username": "", "Password": "" }'

response = requests.post('https://nhl-east-rest.oasis.smt.com/optics3d/v3.30/auth/login', headers=headers, data=data)



token = response.json()['token']

print(token)

def bearer_oauth(r):
    r.headers["Authorization"] = f"Bearer {token}"

    return r

def getGameID(date,homeTeam,awayTeam):
    
    searchString = date+"_"+awayTeam+"@"+homeTeam
    
    url = f'https://nhl-east-rest.oasis.smt.com/optics3d/v3.30/GameSchedule?Year=2022&Scope=4'
    response = requests.get(url, auth=bearer_oauth)
    print(response)
    trackingData = response.json()
 
    for i in range (0,len(trackingData[0]['Events'])):
        if trackingData[0]['Events'][i]['EventId'].find(searchString)>0:
            gameID = trackingData[0]['Events'][i]['EventId']
            startTime = trackingData[0]['Events'][i]['ActualStartUTC']
            endTime = trackingData[0]['Events'][i]['ActualEndUTC']
            print(gameID)
            return gameID, startTime, endTime 
    raise ValueError('Could not find a gameID. Possible date of order of Home/Away is wrong')

confDict = {
    'NJD':'EAST',
    'NYI':'EAST',
    'NYR':'EAST',
    'PHI':'EAST',
    'PIT':'EAST',
    'BOS':'EAST',
    'BUF':'EAST',
    'MTL':'EAST',
    'OTT':'EAST',
    'TOR':'EAST',
    'CAR':'EAST',
    'FLA':'EAST',
    'TBL':'EAST',
    'WSH':'EAST',
    'CHI':'WEST',
    'DET':'EAST',
    'NSH':'WEST',
    'STL':'WEST',
    'CGY':'WEST',
    'COL':'WEST',
    'EDM':'WEST',
    'VAN':'WEST',
    'ANA':'WEST',
    'DAL':'WEST',
    'LAK':'WEST',
    'SJS':'WEST',
    'CBJ':'EAST',
    'MIN':'WEST',
    'WPG':'WEST',
    'ARI':'WEST',
    'VGK':'WEST',
    'SEA':'WEST'
            }

date = '2023_05_13'
home_team = 'SEA'
away_team = 'DAL'

conf = confDict[home_team]

gameID,start_time,end_time = getGameID(date,home_team,away_team)
# Out:
# eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..gnCGadIbxyYx2wp5eW7qsDZ8gqJXsFn45Vsbe8YxkNprrKrPkaCd1z4zwl-15wkUBUghBPdqg_VlocaodyB4rQ
# <Response [200]>
# HOCKEY_NHL_2023_05_13_DAL@SEA_HITS236

# %%
start_time + 7200
# Out:
# 1684026792.574

# %%
# Reads scoreboard data
url = f'https://nhl-{confDict[home_team]}-rest.oasis.smt.com/optics3d/v3.30/Scoreboards?Game={gameID}&StartUTC={start_time}&EndUTC=1684026792.574'
response = requests.get(url, auth=bearer_oauth) 
scoredf = response.json()
scoredf = pd.json_normalize(scoredf)

# %%
# look up approx. StartUTC of event occurrence 

search_StartUTC = scoredf.loc[(scoredf['Period'] == 2)&(scoredf['ClockMinutes'] == 14)&(scoredf['ClockSeconds'] == 25)
                         &(scoredf['EventStatusDetail'] == 'EventStatusDetailGamePlay'),'NowUTC'].iloc[0]

print(search_StartUTC)

EndUTC = search_StartUTC + 2
print(EndUTC)
# Out:
# 1684023704.2228937
# 1684023706.2228937

# %%
url = f'https://nhl-{confDict[home_team]}-rest.oasis.smt.com/optics3d/v3.30/EntityTracking?Game={gameID}&StartUTC={search_StartUTC}&EndUTC={EndUTC}'
response = requests.get(url, auth=bearer_oauth)
print(response)
trackingData = response.json()
tracking_df = pd.json_normalize(trackingData, 'TrackingData')

puck_tracking = tracking_df.loc[tracking_df['EntityId'] == '1']
puck_tracking = puck_tracking.reset_index()
puck_tracking
# Out:
# <Response [200]>
#      index EntityId OnPlayingSurface    LocationUTC PayloadData  \
# 0        2        1             True 1684023706.108          []
# 1        6        1             True 1684023706.092          []
# 2       10        1             True 1684023706.073          []
# 3       14        1             True 1684023706.056          []
# 4       18        1             True 1684023706.037          []
# 5       22        1             True 1684023706.021          []
# 6       26        1             True 1684023706.005          []
# 7       29        1             True 1684023705.989          []
# 8       33        1             True 1684023705.973          []
# 9       37        1             True 1684023705.957          []
# 10      40        1             True 1684023705.941          []
# 11      44        1             True 1684023705.925          []
# 12      48        1             True 1684023705.909          []
# 13      51        1             True 1684023705.893          []
# 14      55        1             True 1684023705.877          []
# 15      58        1             True 1684023705.861          []
# 16      62        1             True 1684023705.844          []
# 17      65        1             True 1684023705.828          []
# 18      69        1             True 1684023705.812          []
# 19      73        1             True 1684023705.796          []
# 20      76        1             True 1684023705.780          []
# 21      80        1             True 1684023705.764          []
# 22      84        1             True 1684023705.732          []
# 23      87        1             True 1684023705.716          []
# 24      91        1             True 1684023705.700          []
# 25      95        1             True 1684023705.684          []
# 26      98        1             True 1684023705.668          []
# 27     101        1             True 1684023705.652          []
# 28     105        1             True 1684023705.636          []
# 29     108        1             True 1684023705.620          []
# 30     112        1             True 1684023705.604          []
# 31     116        1             True 1684023705.588          []
# 32     119        1             True 1684023705.572          []
# 33     123        1             True 1684023705.556          []
# 34     126        1             True 1684023705.540          []
# 35     129        1             True 1684023705.524          []
# 36     133        1             True 1684023705.508          []
# 37     136        1             True 1684023705.492          []
# 38     140        1             True 1684023705.476          []
# 39     143        1             True 1684023705.460          []
# 40     147        1             True 1684023705.444          []
# 41     150        1             True 1684023705.428          []
# 42     153        1             True 1684023705.412          []
# 43     157        1             True 1684023705.396          []
# 44     161        1             True 1684023705.380          []
# 45     164        1             True 1684023705.364          []
# 46     167        1             True 1684023705.348          []
# 47     170        1             True 1684023705.332          []
# 48     173        1             True 1684023705.316          []
# 49     177        1             True 1684023705.300          []
# 50     179        1             True 1684023705.284          []
# 51     183        1             True 1684023705.268          []
# 52     186        1             True 1684023705.252          []
# 53     189        1             True 1684023705.236          []
# 54     193        1             True 1684023705.220          []
# 55     196        1             True 1684023705.204          []
# 56     200        1             True 1684023705.188          []
# 57     203        1             True 1684023705.172          []
# 58     206        1             True 1684023705.156          []
# 59     210        1             True 1684023705.140          []
# 60     213        1             True 1684023705.124          []
# 61     217        1             True 1684023705.108          []
# 62     221        1             True 1684023705.092          []
# 63     224        1             True 1684023705.076          []
# 64     227        1             True 1684023705.060          []
# 65     231        1             True 1684023705.044          []
# 66     235        1             True 1684023705.028          []
# 67     239        1             True 1684023705.012          []
# 68     242        1             True 1684023704.996          []
# 69     246        1             True 1684023704.980          []
# 70     250        1             True 1684023704.964          []
# 71     253        1             True 1684023704.948          []
# 72     257        1             True 1684023704.932          []
# 73     261        1             True 1684023704.916          []
# 74     264        1             True 1684023704.900          []
# 75     268        1             True 1684023704.884          []
# 76     271        1             True 1684023704.868          []
# 77     274        1             True 1684023704.852          []
# 78     279        1             True 1684023704.832          []
# 79     282        1             True 1684023704.817          []
# 80     286        1             True 1684023704.801          []
# 81     289        1             True 1684023704.785          []
# 82     293        1             True 1684023704.769          []
# 83     296        1             True 1684023704.753          []
# 84     299        1             True 1684023704.737          []
# 85     303        1             True 1684023704.721          []
# 86     305        1             True 1684023704.705          []
# 87     309        1             True 1684023704.689          []
# 88     312        1             True 1684023704.673          []
# 89     316        1             True 1684023704.657          []
# 90     320        1             True 1684023704.641          []
# 91     324        1             True 1684023704.625          []
# 92     326        1             True 1684023704.608          []
# 93     330        1             True 1684023704.592          []
# 94     333        1             True 1684023704.576          []
# 95     337        1             True 1684023704.560          []
# 96     341        1             True 1684023704.544          []
# 97     344        1             True 1684023704.528          []
# 98     347        1             True 1684023704.512          []
# 99     350        1             True 1684023704.496          []
# 100    354        1             True 1684023704.480          []
# 101    358        1             True 1684023704.464          []
# 102    361        1             True 1684023704.448          []
# 103    364        1             True 1684023704.432          []
# 104    368        1             True 1684023704.416          []
# 105    371        1             True 1684023704.400          []
# 106    375        1             True 1684023704.384          []
# 107    378        1             True 1684023704.368          []
# 108    382        1             True 1684023704.352          []
# 109    385        1             True 1684023704.336          []
# 110    388        1             True 1684023704.320          []
# 111    391        1             True 1684023704.304          []
# 112    395        1             True 1684023704.288          []
# 113    398        1             True 1684023704.272          []
# 114    402        1             True 1684023704.256          []
# 115    405        1             True 1684023704.240          []
# 116    407        1             True 1684023704.224          []
# 117    411        1             True 1684023704.208          []
# 118    415        1             True 1684023704.192          []
# 119    419        1             True 1684023704.176          []
# 120    422        1             True 1684023704.160          []
# 121    425        1             True 1684023704.144          []
# 122    429        1             True 1684023704.128          []
# 123    432        1             True 1684023704.112          []
#
#     EntityOfficialId         ClockState  SmoothedSpeed  Location.X  \
# 0                     ClockStateRunning            NaN      88.277
# 1                     ClockStateRunning            NaN      88.562
# 2                     ClockStateRunning            NaN      88.817
# 3                     ClockStateRunning            NaN      89.004
# 4                     ClockStateRunning            NaN      89.223
# 5                     ClockStateRunning            NaN      89.361
# 6                     ClockStateRunning            NaN      89.559
# 7                     ClockStateRunning            NaN      89.957
# 8                     ClockStateRunning            NaN      90.153
# 9                     ClockStateRunning            NaN      90.311
# 10                    ClockStateRunning            NaN      90.543
# 11                    ClockStateRunning            NaN      90.655
# 12                    ClockStateRunning            NaN      90.847
# 13                    ClockStateRunning            NaN      90.852
# 14                    ClockStateRunning            NaN      90.263
# 15                    ClockStateRunning            NaN      89.336
# 16                    ClockStateRunning            NaN      88.508
# 17                    ClockStateRunning            NaN      87.686
# 18                    ClockStateRunning            NaN      86.835
# 19                    ClockStateRunning            NaN      86.032
# 20                    ClockStateRunning            NaN      85.149
# 21                    ClockStateRunning            NaN      84.286
# 22                    ClockStateRunning            NaN      82.290
# 23                    ClockStateRunning            NaN      81.126
# 24                    ClockStateRunning            NaN      79.966
# 25                    ClockStateRunning            NaN      78.805
# 26                    ClockStateRunning            NaN      77.663
# 27                    ClockStateRunning            NaN      76.282
# 28                    ClockStateRunning            NaN      74.836
# 29                    ClockStateRunning            NaN      73.399
# 30                    ClockStateRunning            NaN      71.946
# 31                    ClockStateRunning            NaN      70.509
# 32                    ClockStateRunning            NaN      69.030
# 33                    ClockStateRunning            NaN      67.571
# 34                    ClockStateRunning            NaN      66.091
# 35                    ClockStateRunning            NaN      64.616
# 36                    ClockStateRunning            NaN      63.125
# 37                    ClockStateRunning            NaN      61.645
# 38                    ClockStateRunning            NaN      60.148
# 39                    ClockStateRunning            NaN      58.636
# 40                    ClockStateRunning            NaN      57.123
# 41                    ClockStateRunning            NaN      55.606
# 42                    ClockStateRunning            NaN      54.086
# 43                    ClockStateRunning            NaN      52.551
# 44                    ClockStateRunning            NaN      51.027
# 45                    ClockStateRunning            NaN      49.492
# 46                    ClockStateRunning            NaN      47.931
# 47                    ClockStateRunning            NaN      46.373
# 48                    ClockStateRunning            NaN      44.823
# 49                    ClockStateRunning            NaN      43.264
# 50                    ClockStateRunning            NaN      41.715
# 51                    ClockStateRunning            NaN      40.139
# 52                    ClockStateRunning            NaN      38.567
# 53                    ClockStateRunning            NaN      37.000
# 54                    ClockStateRunning            NaN      35.414
# 55                    ClockStateRunning            NaN      33.847
# 56                    ClockStateRunning            NaN      32.454
# 57                    ClockStateRunning            NaN      31.429
# 58                    ClockStateRunning            NaN      30.778
# 59                    ClockStateRunning            NaN      30.461
# 60                    ClockStateRunning            NaN      30.174
# 61                    ClockStateRunning            NaN      29.895
# 62                    ClockStateRunning            NaN      29.624
# 63                    ClockStateRunning            NaN      29.333
# 64                    ClockStateRunning            NaN      29.025
# 65                    ClockStateRunning            NaN      28.765
# 66                    ClockStateRunning            NaN      28.507
# 67                    ClockStateRunning            NaN      28.313
# 68                    ClockStateRunning            NaN      28.169
# 69                    ClockStateRunning            NaN      28.047
# 70                    ClockStateRunning            NaN      27.933
# 71                    ClockStateRunning            NaN      27.849
# 72                    ClockStateRunning            NaN      27.793
# 73                    ClockStateRunning            NaN      27.725
# 74                    ClockStateRunning            NaN      27.687
# 75                    ClockStateRunning            NaN      27.668
# 76                    ClockStateRunning            NaN      27.650
# 77                    ClockStateRunning            NaN      27.631
# 78                    ClockStateRunning            NaN      27.619
# 79                    ClockStateRunning            NaN      27.630
# 80                    ClockStateRunning            NaN      27.658
# 81                    ClockStateRunning            NaN      27.692
# 82                    ClockStateRunning            NaN      27.752
# 83                    ClockStateRunning            NaN      27.853
# 84                    ClockStateRunning            NaN      27.972
# 85                    ClockStateRunning            NaN      28.094
# 86                    ClockStateRunning            NaN      28.220
# 87                    ClockStateRunning            NaN      28.334
# 88                    ClockStateRunning            NaN      28.447
# 89                    ClockStateRunning            NaN      28.562
# 90                    ClockStateRunning            NaN      28.676
# 91                    ClockStateRunning            NaN      28.780
# 92                    ClockStateRunning            NaN      28.906
# 93                    ClockStateRunning            NaN      29.053
# 94                    ClockStateRunning            NaN      29.168
# 95                    ClockStateRunning            NaN      29.303
# 96                    ClockStateRunning            NaN      29.426
# 97                    ClockStateRunning            NaN      29.550
# 98                    ClockStateRunning            NaN      29.647
# 99                    ClockStateRunning            NaN      29.727
# 100                   ClockStateRunning            NaN      29.752
# 101                   ClockStateRunning            NaN      29.685
# 102                   ClockStateRunning            NaN      29.605
# 103                   ClockStateRunning            NaN      29.526
# 104                   ClockStateRunning            NaN      29.451
# 105                   ClockStateRunning            NaN      29.367
# 106                   ClockStateRunning            NaN      29.291
# 107                   ClockStateRunning            NaN      29.215
# 108                   ClockStateRunning            NaN      29.138
# 109                   ClockStateRunning            NaN      29.061
# 110                   ClockStateRunning            NaN      28.975
# 111                   ClockStateRunning            NaN      28.897
# 112                   ClockStateRunning            NaN      28.842
# 113                   ClockStateRunning            NaN      28.755
# 114                   ClockStateRunning            NaN      28.699
# 115                   ClockStateRunning            NaN      28.647
# 116                   ClockStateRunning            NaN      28.597
# 117                   ClockStateRunning            NaN      28.545
# 118                   ClockStateRunning            NaN      28.573
# 119                   ClockStateRunning            NaN      28.583
# 120                   ClockStateRunning            NaN      28.585
# 121                   ClockStateRunning            NaN      28.597
# 122                   ClockStateRunning            NaN      28.601
# 123                   ClockStateRunning            NaN      28.618
#
#      Location.Y  Location.Z  Velocity.X  Velocity.Y  Velocity.Z  \
# 0         0.048       0.000     -17.772       0.968       0.000
# 1         0.033       0.000     -13.455       4.787       0.000
# 2        -0.058       0.000     -10.952       9.253       0.000
# 3        -0.215       0.000     -11.532       1.052       0.000
# 4        -0.235       0.000      -8.632       9.211       0.000
# 5        -0.383       0.000     -12.374       9.800       0.000
# 6        -0.539       0.000     -24.863       1.301       0.000
# 7        -0.560       0.000     -12.289       1.426       0.000
# 8        -0.583       0.000      -9.877      15.181       0.000
# 9        -0.826       0.000     -14.492      -0.118       0.000
# 10       -0.824       0.000      -6.981      10.668       0.000
# 11       -0.995       0.000     -12.022       2.703       0.000
# 12       -1.038       0.000      -0.283       5.149       0.000
# 13       -1.120       0.000      36.816      -5.061       0.000
# 14       -1.039       0.000      57.929      -1.680       0.000
# 15       -1.013       0.000      48.718      -2.826     -26.891
# 16       -0.965       0.457      51.354      -5.686     -27.998
# 17       -0.874       0.905      53.154      -1.899     -24.195
# 18       -0.843       1.292      50.202      -3.459     -24.787
# 19       -0.788       1.689      55.198      -6.031     -15.731
# 20       -0.691       1.941      53.954      -1.712     -19.079
# 21       -0.664       2.246      62.362      -4.965     -25.910
# 122         -29.170         -16.753           0.000
# 123         -20.075          13.432           0.000

# %%
def check_high_sticking(puck_tracking):
    
    # Extract the puck location and velocity in the Z direction
    loc_z = puck_tracking['Location.Z'].values
    vel_z = puck_tracking['Velocity.Z'].values
    
    # Detect when the velocity in z changes sign between rows
    vel_z_sign = np.sign(vel_z)
    sign_change = np.abs(vel_z_sign - np.roll(vel_z_sign, 1)) > 0
    
    # Find the max height of the puck for the 3 rows closest to each indicator
    max_height = np.zeros(len(puck_tracking))
    for i in range(1, len(puck_tracking)):
        if sign_change[i]:
            max_height[i-1:i+2] = np.max(loc_z[i-1:i+2])
    
    # Identify the rows where the puck is above the cross-bar
    high_puck = loc_z > 4
    
    # Identify the rows where the puck has been high-sticked
    high_stick_rows = np.nonzero(high_puck & (max_height > 4))[0]
    
    # Determine if the puck has been high-sticked
    if len(high_stick_rows) > 0:
        print(f"high-sticking. the puck was hit at a height of {max_height[high_stick_rows[0]]}.")
        return True
    else:
        print(f"no high-sticking.")
        return False

# %%
check_high_sticking(puck_tracking)
# Out:
# high-sticking. the puck was hit at a height of 4.620785653281009.
# True

# %%
def detect_raised_stick(image_path):
    # Load the image
    image = cv2.imread(image_path)
    
    # Convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Apply a bilateral filter to reduce noise while preserving edges
    gray = cv2.bilateralFilter(gray, 11, 17, 17)

    # Detect edges using the Canny algorithm
    edges = cv2.Canny(gray, 30, 200)

    # Find contours in the edge map
    contours, hierarchy = cv2.findContours(edges, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

    # Loop over the contours and find the one that corresponds to the stick
    for contour in contours:
        # Compute the area and perimeter of the contour
        area = cv2.contourArea(contour)
        perimeter = cv2.arcLength(contour, True)
        
        # Approximate the contour as a polygon with fewer vertices
        epsilon = 0.01 * perimeter
        approx = cv2.approxPolyDP(contour, epsilon, True)
        
        # If the polygon has 4 vertices, it could be the stick
        if len(approx) == 4:
            # Compute the aspect ratio of the bounding box around the contour
            x,y,w,h = cv2.boundingRect(contour)
            aspect_ratio = float(w)/h
            
            # If the aspect ratio is within a certain range, the stick is likely raised
            if aspect_ratio > 1.2 and aspect_ratio < 3.0:
                return True
    
    # If no raised stick is detected, return False
    return False

# %%
image_path = "/Users/SFarquharson/Documents/images_high_stick/connor-bedard-09122022.avif"
stick_raised = detect_raised_stick(image_path)
if stick_raised:
    print("The stick is raised!")
else:
    print("The stick is not raised.")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /var/folders/x0/gg1b8ssd5vn841f1wx93xtp40000gp/T/ipykernel_61699/3303053863.py in <module>
#       1 image_path = "/Users/SFarquharson/Documents/images_high_stick/connor-bedard-09122022.avif"
# ----> 2 stick_raised = detect_raised_stick(image_path)
#       3 if stick_raised:
#       4     print("The stick is raised!")
#       5 else:
#
# /var/folders/x0/gg1b8ssd5vn841f1wx93xtp40000gp/T/ipykernel_61699/429677554.py in detect_raised_stick(image_path)
#       4
#       5     # Convert the image to grayscale
# ----> 6     gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       7
#       8     # Apply a bilateral filter to reduce noise while preserving edges
#
# error: OpenCV(4.6.0) /private/var/folders/nz/j6p8yfhx1mv_0grj5xl4650h0000gp/T/abs_562_cazh1h/croots/recipe/opencv-suite_1664548333142/work/modules/imgproc/src/color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
